# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df_cust=pd.read_csv("input/h-and-m-personalized-fashion-recommendations/customers.csv")
df_articles=pd.read_csv("input/h-and-m-personalized-fashion-recommendations/articles.csv")
df_trx=pd.read_csv("input/h-and-m-personalized-fashion-recommendations/transactions_train.csv")

# %% [markdown]
# ## Customer Data Cleaning

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1371980 entries, 0 to 1371979
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   customer_id             1371980 non-null  object
#  1   FN                      476930 non-null   float64
#  2   Active                  464404 non-null   float64
#  3   club_member_status      1365918 non-null  object
#  4   fashion_news_frequency  1355971 non-null  object
#  5   age                     1356119 non-null  float64
#  6   postal_code             1371980 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ MB

# %%
df_cust.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...

# %% [markdown]
# #### We can see there are some null values in columns: 'FN','Active','club_member_status','fashion_news_frequency'
# #### And column 'fashion_news_frequency' has 2 'None' values instead of 'NONE'

# %%
for i in['FN','Active','club_member_status','fashion_news_frequency']:
    print("null values: ",df_cust[i].isna().sum())
    print(df_cust[i].value_counts())
    print("----------------------------")
# Out:
# null values:  895050
# 1.0    476930
# Name: FN, dtype: int64
# ----------------------------
# null values:  907576
# 1.0    464404
# Name: Active, dtype: int64
# ----------------------------
# null values:  6062
# ACTIVE        1272491
# PRE-CREATE      92960
# LEFT CLUB         467
# Name: club_member_status, dtype: int64
# ----------------------------
# null values:  16009
# NONE         877711
# Regularly    477416
# Monthly         842
# None              2
# Name: fashion_news_frequency, dtype: int64
# ----------------------------

# %% [markdown]
# #### Replacing NaN values in FN and Active columns with 0
# #### Replacing NaN values in club_member_status column with "ACTIVE" and in fashion_news_frequency column with "NONE" as they are mode values

# %%
df_cust['FN'].fillna(value=0,inplace=True)
df_cust['Active'].fillna(value=0,inplace=True)
df_cust['club_member_status'].fillna(value="ACTIVE",inplace=True)
df_cust['fashion_news_frequency'].fillna(value="NONE",inplace=True)

# %% [markdown]
# #### Replacing 2 "None" values with "NONE"

# %%
df_cust['fashion_news_frequency']=df_cust['fashion_news_frequency'].apply(lambda x: "NONE" if x=="None" else x)

# %%
for i in['FN','Active','club_member_status','fashion_news_frequency']:
    print("null values: ",df_cust[i].isna().sum())
    print(df_cust[i].value_counts())
    print("----------------------------")
# Out:
# null values:  0
# 0.0    895050
# 1.0    476930
# Name: FN, dtype: int64
# ----------------------------
# null values:  0
# 0.0    907576
# 1.0    464404
# Name: Active, dtype: int64
# ----------------------------
# null values:  0
# ACTIVE        1278553
# PRE-CREATE      92960
# LEFT CLUB         467
# Name: club_member_status, dtype: int64
# ----------------------------
# null values:  0
# NONE         893722
# Regularly    477416
# Monthly         842
# Name: fashion_news_frequency, dtype: int64
# ----------------------------

# %% [markdown]
# ## Articles Data Cleaning

# %%
df_articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  object
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  object
#  5   product_group_name            105542 non-null  object
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  object
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  object
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  object
#  12  perceived_colour_master_id    105542 non-null  int64
#  13  perceived_colour_master_name  105542 non-null  object
#  14  department_no                 105542 non-null  int64
#  15  department_name               105542 non-null  object
#  16  index_code                    105542 non-null  object
#  17  index_name                    105542 non-null  object
#  18  index_group_no                105542 non-null  int64
#  19  index_group_name              105542 non-null  object
#  20  section_no                    105542 non-null  int64
#  21  section_name                  105542 non-null  object
#  22  garment_group_no              105542 non-null  int64
#  23  garment_group_name            105542 non-null  object
#  24  detail_desc                   105126 non-null  object
# dtypes: int64(11), object(14)
# memory usage: 20.1+ MB

# %%
df_articles.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    department_name index_code        index_name index_group_no  \
# 0     Jersey Basic          A        Ladieswear              1
# 1     Jersey Basic          A        Ladieswear              1
# 2     Jersey Basic          A        Ladieswear              1
# 3   Clean Lingerie          B  Lingeries/Tights              1
# 4   Clean Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no            section_name garment_group_no  \
# 0        Ladieswear         16  Womens Everyday Basics             1002
# 1        Ladieswear         16  Womens Everyday Basics             1002
# 2        Ladieswear         16  Womens Everyday Basics             1002
# 3        Ladieswear         61         Womens Lingerie             1017
# 4        Ladieswear         61         Womens Lingerie             1017
#
#    garment_group_name                                        detail_desc
# 0        Jersey Basic            Jersey top with narrow shoulder straps.
# 1        Jersey Basic            Jersey top with narrow shoulder straps.
# 2        Jersey Basic            Jersey top with narrow shoulder straps.
# 3   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
#
# [5 rows x 25 columns]

# %% [markdown]
# #### We see the number of codes do not match the number of respective names for some columns like product name and code

# %%
df_articles.nunique().sort_values()
# Out:
# index_group_no                       5
# index_group_name                     5
# perceived_colour_value_id            8
# perceived_colour_value_name          8
# index_name                          10
# index_code                          10
# product_group_name                  19
# perceived_colour_master_name        20
# perceived_colour_master_id          20
# garment_group_name                  21
# garment_group_no                    21
# graphical_appearance_name           30
# graphical_appearance_no             30
# colour_group_name                   50
# colour_group_code                   50
# section_name                        56
# section_no                          57
# product_type_name                  131
# product_type_no                    132
# department_name                    250
# department_no                      299
# detail_desc                      43404
# prod_name                        45875
# product_code                     47224
# article_id                      105542
# dtype: int64

# %% [markdown]
# #### Creating dictionaries for name and code combinations

# %%
graphical_appearance=pd.Series(df_articles.graphical_appearance_name.values,
                               index=df_articles.graphical_appearance_no).sort_index().to_dict()
index_group=pd.Series(df_articles.index_group_name.values,
                               index=df_articles.index_group_no).sort_index().to_dict()
perceived_colour_value=pd.Series(df_articles.perceived_colour_value_name.values,
                               index=df_articles.perceived_colour_value_id).sort_index().to_dict()
index=pd.Series(df_articles.index_name.values,
                               index=df_articles.index_code).sort_index().to_dict()
perceived_colour_master=pd.Series(df_articles.perceived_colour_master_name.values,
                               index=df_articles.perceived_colour_master_id).sort_index().to_dict()
garment_group=pd.Series(df_articles.garment_group_name.values,
                               index=df_articles.garment_group_no).sort_index().to_dict()
colour_group=pd.Series(df_articles.colour_group_name.values,
                               index=df_articles.colour_group_code).sort_index().to_dict()
section=pd.Series(df_articles.section_name.values,
                               index=df_articles.section_no).sort_index().to_dict()
department=pd.Series(df_articles.department_name.values,
                               index=df_articles.department_no).sort_index().to_dict()
product_type=pd.Series(df_articles.product_type_name.values,
                               index=df_articles.product_type_no).sort_index().to_dict()
product=pd.Series(df_articles.prod_name.values,
                               index=df_articles.product_code).sort_index().to_dict()
dict_list={'graphical_appearance':graphical_appearance,'index_group':index_group,'perceived_colour_value':perceived_colour_value,
           'index':index, 'perceived_colour_master':perceived_colour_master,'garment_group':garment_group,
          'colour_group':colour_group,'section':section,'department':department,'product_type':product_type,
          "product": product}

# %%
dict_list
# Out:
# {'graphical_appearance': {-1: 'Unknown',
#   1010001: 'All over pattern',
#   1010002: 'Application/3D',
#   1010003: 'Argyle',
#   1010004: 'Check',
#   1010005: 'Colour blocking',
#   1010006: 'Dot',
#   1010007: 'Embroidery',
#   1010008: 'Front print',
#   1010009: 'Glittering/Metallic',
#   1010010: 'Melange',
#   1010011: 'Metallic',
#   1010012: 'Mixed solid/pattern',
#   1010013: 'Other pattern',
#   1010014: 'Placement print',
#   1010015: 'Sequin',
#   1010016: 'Solid',
#   1010017: 'Stripe',
#   1010018: 'Treatment',
#   1010019: 'Transparent',
#   1010020: 'Contrast',
#   1010021: 'Lace',
#   1010022: 'Jacquard',
#   1010023: 'Denim',
#   1010024: 'Chambray',
#   1010025: 'Slub',
#   1010026: 'Other structure',
#   1010027: 'Neps',
#   1010028: 'Mesh',
#   1010029: 'Hologram'},
#  'index_group': {1: 'Ladieswear',
#   2: 'Divided',
#   3: 'Menswear',
#   4: 'Baby/Children',
#   26: 'Sport'},
#  'perceived_colour_value': {-1: 'Unknown',
#   1: 'Dusty Light',
#   2: 'Medium Dusty',
#   3: 'Light',
#   4: 'Dark',
#   5: 'Bright',
#   6: 'Undefined',
#   7: 'Medium'},
#  'index': {'A': 'Ladieswear',
#   'B': 'Lingeries/Tights',
#   'C': 'Ladies Accessories',
#   'D': 'Divided',
#   'F': 'Menswear',
#   'G': 'Baby Sizes 50-98',
#   'H': 'Children Sizes 92-140',
#   'I': 'Children Sizes 134-170',
#   'J': 'Children Accessories, Swimwear',
#   'S': 'Sport'},
#  'perceived_colour_master': {-1: 'Unknown',
#   1: 'Mole',
#   2: 'Blue',
#   3: 'Orange',
#   4: 'Pink',
#   5: 'Black',
#   6: 'Lilac Purple',
#   7: 'Turquoise',
#   8: 'Yellow',
#   9: 'White',
#   10: 'Yellowish Green',
#   11: 'Beige',
#   12: 'Grey',
#   13: 'Brown',
#   14: 'undefined',
#   15: 'Metal',
#   16: 'Bluish Green',
#   18: 'Red',
#   19: 'Green',
#   20: 'Khaki green'},
#  'garment_group': {1001: 'Unknown',
#   1002: 'Jersey Basic',
#   1003: 'Knitwear',
#   1005: 'Jersey Fancy',
#   1006: 'Woven/Jersey/Knitted mix Baby',
#   1007: 'Outdoor',
#   1008: 'Dressed',
#   1009: 'Trousers',
#   1010: 'Blouses',
#   1011: 'Shirts',
#   1012: 'Skirts',
#   1013: 'Dresses Ladies',
#   1014: 'Dresses/Skirts girls',
#   1016: 'Trousers Denim',
#   1017: 'Under-, Nightwear',
#   1018: 'Swimwear',
#   1019: 'Accessories',
#   1020: 'Shoes',
#   1021: 'Socks and Tights',
#   1023: 'Special Offers',
#   1025: 'Shorts'},
#  'colour_group': {-1: 'Unknown',
#   1: 'Other',
#   2: 'Transparent',
#   3: 'Silver',
#   4: 'Bronze/Copper',
#   5: 'Gold',
#   6: 'Light Grey',
#   7: 'Grey',
#   8: 'Dark Grey',
#   9: 'Black',
#   10: 'White',
#   11: 'Off White',
#   12: 'Light Beige',
#   13: 'Beige',
#   14: 'Dark Beige',
#   15: 'Greyish Beige',
#   17: 'Yellowish Brown',
#   19: 'Greenish Khaki',
#   20: 'Other Yellow',
#   21: 'Light Yellow',
#   22: 'Yellow',
#   23: 'Dark Yellow',
#   30: 'Other Orange',
#   31: 'Light Orange',
#   32: 'Orange',
#   33: 'Dark Orange',
#   40: 'Other Red',
#   41: 'Light Red',
#   42: 'Red',
#   43: 'Dark Red',
#   50: 'Other Pink',
#   51: 'Light Pink',
#   52: 'Pink',
#   53: 'Dark Pink',
#   60: 'Other Purple',
#   61: 'Light Purple',
#   62: 'Purple',
#   63: 'Dark Purple',
#   70: 'Other Blue',
#   71: 'Light Blue',
#   72: 'Blue',
#   73: 'Dark Blue',
#   80: 'Other Turquoise',
#   81: 'Light Turquoise',
#   82: 'Turquoise',
#   83: 'Dark Turquoise',
#   90: 'Other Green',
#   91: 'Light Green',
#   92: 'Green',
#   93: 'Dark Green'},
#  'section': {2: 'H&M+',
#   4: 'Ladies Other',
#   5: 'Ladies H&M Sport',
#   6: 'Womens Casual',
#   8: 'Mama',
#   11: 'Womens Tailoring',
#   14: 'Womens Premium',
#   15: 'Womens Everyday Collection',
#   16: 'Womens Everyday Basics',
#   17: 'Ladies Other',
#   18: 'Womens Trend',
#   19: 'Womens Jackets',
#   20: 'Contemporary Smart',
#   21: 'Contemporary Casual',
#   22: 'Men H&M Sport',
#   23: 'Men Suits & Tailoring',
#   24: 'Men Project',
#   25: 'Men Accessories',
#   26: 'Men Underwear',
#   27: 'Men Shoes',
#   28: 'Men Edition',
#   29: 'Men Other',
#   30: 'Men Other 2',
#   31: 'Mens Outerwear',
#   40: 'Baby Girl',
#   41: 'Baby Boy',
#   42: 'Kids & Baby Shoes',
#   43: 'Kids Accessories, Swimwear & D',
#   44: 'Baby Essentials & Complements',
#   45: 'Kids Outerwear',
#   46: 'Kids Boy',
#   47: 'Young Boy',
#   48: 'Kids Local Relevance',
#   49: 'Kids Sports',
#   50: 'Divided Projects',
#   51: 'Divided Basics',
#   52: 'Divided Accessories',
#   53: 'Divided Collection',
#   55: 'Contemporary Street',
#   56: 'Denim Men',
#   57: 'Ladies Denim',
#   58: 'Divided Selected',
#   60: 'Womens Swimwear, beachwear',
#   61: 'Womens Lingerie',
#   62: 'Womens Nightwear, Socks & Tigh',
#   64: 'Womens Shoes',
#   65: 'Womens Big accessories',
#   66: 'Womens Small accessories',
#   70: 'Divided Asia keys',
#   71: 'EQ Divided',
#   72: 'Boys Underwear & Basics',
#   76: 'Kids Girl',
#   77: 'Young Girl',
#   79: 'Girls Underwear & Basics',
#   80: 'Divided Complements Other',
#   82: 'Special Collections',
#   97: 'Collaborations'},
#  'department': {1201: 'Outwear',
#   1202: 'Jackets',
#   1212: 'Suit',
#   1222: 'Suit jacket',
#   1241: 'Outwear & Blazers',
#   1244: 'Outdoor/Blazers',
#   1310: 'Dress',
#   1313: 'Dress',
#   1322: 'Dress',
#   1334: 'Casual Lingerie',
#   1336: 'Shopbasket Lingerie',
#   1338: 'Expressive Lingerie',
#   1339: 'Clean Lingerie',
#   1343: 'Projects Dresses',
#   1344: 'Dresses',
#   1352: 'Equatorial',
#   1410: 'Shorts & Skirts',
#   1414: 'Skirt',
#   1422: 'Skirt',
#   1444: 'Skirts',
#   1447: 'Skirts DS',
#   1510: 'Blouse',
#   1515: 'Blouse',
#   1522: 'Blouse',
#   1543: 'Tops Woven',
#   1545: 'Projects Woven Tops',
#   1547: 'Tops woven DS',
#   1610: 'Knitwear',
#   1612: 'Jersey/Knitwear Premium',
#   1616: 'Knitwear',
#   1620: 'Jersey inactive from S.6',
#   1626: 'Knitwear',
#   1636: 'Jersey fancy',
#   1640: 'Tops Fancy Jersey',
#   1641: 'Jersey',
#   1642: 'Shorts DS',
#   1643: 'Basic 1',
#   1644: 'Projects Jersey & Knitwear',
#   1645: 'Divided Swimwear',
#   1646: 'Knitwear Basic',
#   1647: 'Tops Knitwear',
#   1648: 'Knitwear',
#   1649: 'Trousers DS',
#   1652: 'Divided+',
#   1660: 'Jersey',
#   1666: 'Jersey',
#   1670: 'Jersey License',
#   1676: 'Jersey Basic',
#   1686: 'Jersey Occasion',
#   1710: 'Trouser',
#   1717: 'Trouser',
#   1722: 'Trouser',
#   1723: 'Shorts',
#   1727: 'Test Ladies',
#   1743: 'Projects Woven Bottoms',
#   1744: 'AK Bottoms',
#   1745: 'Shorts',
#   1747: 'Trousers',
#   1752: 'Bottoms',
#   1772: 'Denim Trousers',
#   1773: 'Denim Other Garments',
#   1774: 'OL Extended Sizes',
#   1778: 'OL Extended Sizes',
#   1779: 'Everyday Waredrobe Denim',
#   1909: 'Woven top',
#   1912: 'Woven Premium',
#   1919: 'Jersey',
#   1920: 'Small Bags',
#   1926: 'Woven Occasion',
#   1929: 'Outwear',
#   1939: 'Woven bottoms',
#   1941: 'Blouse & Dress',
#   1948: 'Trousers & Skirt',
#   1949: 'Knitwear',
#   2031: 'Woven bottoms',
#   2032: 'Jersey',
#   2033: 'Woven Tops',
#   2034: 'Knitwear',
#   2035: 'Nursing',
#   2080: 'Studio Collection',
#   2930: 'Baby Girl Local Relevance',
#   2932: 'Baby Boy Local Relevance',
#   2950: 'Baby Toys/Acc',
#   3000: 'Limited Edition',
#   3030: 'Equatorial Assortment',
#   3040: 'Premium Quality',
#   3080: 'Take Care External',
#   3090: 'Campaigns',
#   3209: 'Bags',
#   3409: 'Scarves',
#   3419: 'Other items',
#   3420: 'Small Accessories Extended',
#   3439: 'EQ & Special Collections',
#   3509: 'Belts',
#   3510: 'Accessories',
#   3519: 'Gloves/Hats',
#   3527: 'Flats',
#   3528: 'Heels',
#   3529: 'Boots',
#   3608: 'Tights basic',
#   3610: 'Socks',
#   3611: 'Shopbasket Socks',
#   3629: 'Shoes',
#   3630: 'Shoes / Boots inactive from s5',
#   3705: 'Mama Lingerie',
#   3708: 'Loungewear',
#   3709: 'Nightwear',
#   3710: 'Functional Lingerie',
#   3828: 'Sneakers',
#   3929: 'Divided Shoes',
#   3931: 'Accessories Other',
#   3932: 'Tops & Bottoms Other',
#   3936: 'EQ Divided Basics',
#   3937: 'UW',
#   3938: 'EQ Ladies Denim',
#   3939: 'Shoes Other',
#   3941: 'Accessories',
#   3943: 'EQ Divided Blue',
#   3944: 'Bags',
#   3945: 'Knit & Woven',
#   3946: 'Small Accessories',
#   3948: 'Other Accessories',
#   4020: 'AK Tops Jersey & Woven',
#   4030: 'AK Other',
#   4090: 'Promotion/ Other /Offer',
#   4091: 'Price Items',
#   4092: 'Read & React',
#   4210: 'Kids Boy Swimwear',
#   4211: 'Kids Boy Shoes',
#   4212: 'Kids Boy Big Acc',
#   4213: 'Boys Small Acc & Bags',
#   4214: 'Kids Boy Socks',
#   4215: 'Kids Boy UW/NW',
#   4216: 'Dress-up Boys',
#   4220: 'Young boy Swimwear',
#   4221: 'Young Boy Shoes',
#   4222: 'Young Boy Big Acc',
#   4224: 'Young Boy Socks',
#   4225: 'Young Boy UW/NW',
#   4242: 'Swimwear',
#   4310: 'Kids Girl Swimwear',
#   4311: 'Kids Girl Shoes',
#   4312: 'Kids Girl Big Acc',
#   4313: 'Girls Small Acc/Bags',
#   4314: 'Kids Dress-up/Football',
#   4317: 'Sneakers small girl inactive from s2',
#   4320: 'Young Girl Swimwear',
#   4321: 'Young Girl Shoes',
#   4322: 'Young Girl Big Acc',
#   4323: 'Small Acc. Jewellery & Other',
#   4327: 'Sneakers big girl inactive from s2',
#   4342: 'EQ & Special Collections',
#   4343: 'Hair Accessories',
#   4344: 'Jewellery',
#   4345: 'Jewellery Extended',
#   4920: 'Take care',
#   5131: 'Blazer',
#   5231: 'Jacket',
#   5252: 'Jacket Casual',
#   5262: 'Jacket Smart',
#   5283: 'Jacket Street',
#   5454: 'Suit Extended inactive from s1',
#   5555: 'Blazer',
#   5626: 'AK Dresses & Outdoor',
#   5627: 'AK Tops Knitwear',
#   5631: 'Trouser',
#   5641: 'Local relevance',
#   5656: 'Trouser',
#   5658: 'Shorts',
#   5672: 'Denim trousers',
#   5673: 'Denim shorts',
#   5679: 'Denim wardrobe H&M man inactive from S.6',
#   5683: 'Trouser',
#   5686: 'Trouser',
#   5687: 'Shorts',
#   5690: 'Shorts',
#   5731: 'Shirt',
#   5741: 'Projects',
#   5767: 'Shirt',
#   5777: 'Shirt',
#   5783: 'Shirt',
#   5787: 'Shirt Extended inactive from s1',
#   5828: 'Jersey Fancy',
#   5831: 'Knitwear',
#   5832: 'Light Basic Jersey',
#   5833: 'Heavy Basic Jersey',
#   5848: 'Jersey Fancy',
#   5858: 'Knitwear',
#   5868: 'Basics',
#   5878: 'Knitwear',
#   5882: 'Jersey Fancy',
#   5883: 'Jersey Basic',
#   5884: 'Knitwear',
#   5888: 'Blanks',
#   5950: 'On Demand',
#   5952: 'Outdoor inactive from s1',
#   5956: 'Woven inactive from s1',
#   5957: 'Jersey inactive from s1',
#   5958: 'Knitwear inactive from s1',
#   5959: 'Divided+ inactive from s.1',
#   5960: 'Outdoor/Blazers DS',
#   5961: 'Dresses DS',
#   5962: 'Jersey Fancy DS',
#   5963: 'Tops Knitwear DS',
#   5999: 'Socks Wall',
#   6280: 'Tops Girls',
#   6281: 'Bottoms Girls',
#   6283: 'Tops Boys',
#   6512: 'Baby Boy Outdoor',
#   6515: 'Baby basics',
#   6525: 'Baby Girl Jersey Fancy',
#   6526: 'Baby Girl Knitwear',
#   6541: 'Baby Socks',
#   6545: 'Baby Boy Jersey Fancy',
#   6546: 'Baby Boy Knitwear',
#   6550: 'Baby Girl Outdoor',
#   6555: 'Baby Girl Woven',
#   6557: 'Baby Exclusive',
#   6561: 'Baby Shoes',
#   6563: 'Baby Nightwear',
#   6564: 'Newborn',
#   6565: 'Baby Boy Woven',
#   7020: 'Conscious Exclusive',
#   7050: 'Promotion / Other / Offer',
#   7188: 'Socks Bin',
#   7388: 'Bags & Items',
#   7389: 'Belts',
#   7510: 'Woven',
#   7520: 'Knitwear',
#   7530: 'Accessories',
#   7613: 'Kids Girl Dresses',
#   7616: 'Kids Girl Jersey Fancy',
#   7617: 'Kids Girl Trouser',
#   7618: 'Kids Girl Knitwear',
#   7648: 'Kids Boy Jersey Fancy',
#   7655: 'Kids Boy Shorts',
#   7656: 'Kids Boy Trouser',
#   7657: 'Kids Boy Shirt',
#   7658: 'Kids Boy Knitwear',
#   7659: 'Kids Boy License',
#   7668: 'Kids Boy Jersey Basic',
#   7757: 'Kids Girl Exclusive',
#   7812: 'Kids Girl Outdoor',
#   7814: 'Girls Local Relevance',
#   7819: 'Kids Girl License',
#   7848: 'Boys Local Relevance',
#   7852: 'Kids Boy Outdoor',
#   7854: 'Girls Projects',
#   7857: 'Kids Boy Exclusive',
#   7912: 'Asia Assortment',
#   7917: 'Kids Girl Denim',
#   7920: 'Kids Girl Jersey Basic',
#   7921: 'Kids Girl S&T',
#   7922: 'Kids Girl UW/NW',
#   7930: 'Young Girl Jersey Basic',
#   7931: 'Young Girl S&T',
#   7932: 'Young Girl UW/NW',
#   7952: 'Jersey License',
#   7956: 'Kids Boy Denim',
#   7987: 'Underwear Woven',
#   7988: 'Underwear Jersey',
#   7989: 'Underwear Jersey Fancy inactive from s1',
#   8030: 'EQ H&M Man',
#   8090: 'Promotion/Other/Offer',
#   8310: 'Ladies Sport Bottoms',
#   8316: 'Ladies Sport Bras',
#   8394: 'Men Sport Bottoms',
#   8396: 'Ladies Sport Acc',
#   8397: 'Ladies Sport Woven',
#   8398: 'Woven bottoms inactive from S.7',
#   8558: 'Men Sport Tops',
#   8559: 'Men Sport Woven',
#   8560: 'Men Sport Acc',
#   8563: 'Bottoms Boys',
#   8564: 'Accessories Boys',
#   8615: 'Blazer S&T',
#   8616: 'Trouser S&T',
#   8617: 'Shirt S&T',
#   8713: 'Young Girl Dresses',
#   8716: 'Young Girl Jersey Fancy',
#   8717: 'Young Girl Trouser',
#   8718: 'Young Girl Knitwear',
#   8748: 'Young Boy Jersey Fancy',
#   8755: 'Young Boy Shorts',
#   8756: 'Young Boy Trouser',
#   8757: 'Young Boy Shirt',
#   8758: 'Young Boy Knitwear',
#   8768: 'Young Boy Jersey Basic',
#   8812: 'Young Girl Outdoor',
#   8815: 'License',
#   8852: 'Young Boy Outdoor',
#   8888: 'Sunglasses',
#   8917: 'Young Girl Denim',
#   8956: 'Young Boy Denim',
#   9020: 'Special Collection',
#   9984: 'Swimwear',
#   9985: 'Accessories',
#   9986: 'Small Accessories',
#   9989: 'Loungewear'},
#  'product_type': {-1: 'Unknown',
#   49: 'Sleeping sack',
#   57: 'Swimsuit',
#   59: 'Swimwear bottom',
#   60: 'Swimwear top',
#   66: 'Bag',
#   67: 'Belt',
#   68: 'Bracelet',
#   69: 'Cap/peaked',
#   70: 'Earring',
#   71: 'Gloves',
#   72: 'Hair clip',
#   73: 'Hair string',
#   74: 'Hair/alice band',
#   75: 'Hat/beanie',
#   76: 'Hat/brim',
#   77: 'Necklace',
#   78: 'Other accessories',
#   79: 'Ring',
#   80: 'Scarf',
#   81: 'Sunglasses',
#   82: 'Tie',
#   83: 'Umbrella',
#   84: 'Wallet',
#   85: 'Watch',
#   86: 'Ballerinas',
#   87: 'Boots',
#   88: 'Flip flop',
#   89: 'Other shoe',
#   90: 'Pumps',
#   91: 'Sandals',
#   92: 'Heeled sandals',
#   93: 'Slippers',
#   94: 'Sneakers',
#   95: 'Wedge',
#   96: 'Chem. cosmetics',
#   98: 'Fine cosmetics',
#   100: 'Bootie',
#   102: 'Moccasins',
#   144: 'Flat shoe',
#   155: 'Soft Toys',
#   156: 'Waterbottle',
#   161: 'Giftbox',
#   196: 'Sleep Bag',
#   230: 'Heels',
#   231: 'Dog Wear',
#   245: 'Cardigan',
#   252: 'Sweater',
#   253: 'Vest top',
#   254: 'Top',
#   255: 'T-shirt',
#   256: 'Bodysuit',
#   257: 'Polo shirt',
#   258: 'Blouse',
#   259: 'Shirt',
#   260: 'Tailored Waistcoat',
#   261: 'Outdoor Waistcoat',
#   262: 'Jacket',
#   263: 'Coat',
#   264: 'Blazer',
#   265: 'Dress',
#   267: 'Jumpsuit/Playsuit',
#   268: 'Dungarees',
#   270: 'Garment Set',
#   271: 'Outdoor overall',
#   272: 'Trousers',
#   273: 'Leggings/Tights',
#   274: 'Shorts',
#   275: 'Skirt',
#   276: 'Outdoor trousers',
#   277: 'Costumes',
#   283: 'Underwear body',
#   284: 'Underwear corset',
#   285: 'Underdress',
#   286: 'Underwear bottom',
#   287: 'Long John',
#   288: 'Underwear set',
#   289: 'Nipple covers',
#   291: 'Bra extender',
#   293: 'Night gown',
#   295: 'Pyjama jumpsuit/playsuit',
#   296: 'Pyjama bottom',
#   297: 'Pyjama set',
#   298: 'Bikini top',
#   299: 'Swimwear set',
#   300: 'Sarong',
#   302: 'Socks',
#   303: 'Leg warmers',
#   304: 'Underwear Tights',
#   305: 'Robe',
#   306: 'Bra',
#   307: 'Kids Underwear top',
#   308: 'Hoodie',
#   326: 'Side table',
#   349: 'Blanket',
#   351: 'Cushion',
#   366: 'Towel',
#   389: 'Toy',
#   464: 'Pre-walkers',
#   465: 'Flat shoes',
#   467: 'Backpack',
#   468: 'Bumbag',
#   470: 'Cross-body bag',
#   475: 'Tote bag',
#   476: 'Shoulder bag',
#   477: 'Weekend/Gym bag',
#   483: 'Clothing mist',
#   489: 'Sewing kit',
#   491: 'Stain remover spray',
#   492: 'Washing bag',
#   493: 'Wood balls',
#   494: 'Accessories set',
#   495: 'Alice band',
#   496: 'Beanie',
#   498: 'Baby Bib',
#   499: 'Braces',
#   503: 'Bucket hat',
#   504: 'Cap',
#   508: 'Earrings',
#   509: 'Felt hat',
#   510: 'Eyeglasses',
#   511: 'Hairband',
#   512: 'Hair ties',
#   514: 'Headband',
#   515: 'Straw hat',
#   521: 'Dog wear',
#   523: 'Wireless earphone case',
#   525: 'Keychain',
#   529: 'Mobile case',
#   532: 'Umbrella',
#   761: 'Marker pen',
#   762: 'Zipper head'},
#  'product': {108775: 'Strap top (1)',
#   110065: 'OP T-shirt (Idro)',
#   111565: '20 den 1p Stockings',
#   111586: 'Shape Up 30 den 1p Tights',
#   111593: 'Support 40 den 1p Tights',
#   111609: '200 den 1p Tights',
#   112679: 'SWEATSHIRT  OC',
#   114428: 'Alice BANDEAU 2-p',
#   116379: 'Frugan longsleeve',
#   118458: 'Jerry jogger bottoms',
#   120129: 'Babette long',
#   123173: 'Control Top 50 den 1p Tights',
#   126589: '2p Claw',
#   129085: 'Pirate Leggings (1)',
#   130035: 'Black Umbrella',
#   141661: 'Velour pyjama',
#   144993: 'Mama 100 den 1p Tights',
#   145872: 'Dorian l/s basic',
#   146706: '3P TANKTOP BODY',
#   146721: 'Hair Ring',
#   146730: '200 den 1p leggings',
#   147339: '6P SS BODY',
#   148033: 'Nouvelle 1p Stay Up',
#   150959: 'THOMPSON woven sport pants',
#   153115: 'OP Strapless^',
#   156224: 'Box 4p Socks',
#   156227: 'Box 4p Kneehighs',
#   156231: 'Box 4p Tights',
#   156289: 'Slim Cheapo 79',
#   156610: 'Anton sport pant',
#   158340: 'Highwaist 30 den 1p Tights',
#   160442: '3p Sneaker Socks',
#   162074: 'Sigge sneaker sock 5p',
#   163734: 'KOMPIS 2-pack L/S',
#   164912: 'Scallop 5p Socks',
#   174057: 'FLEECE PYJAMA',
#   176209: 'Mr Harrington w/hood',
#   176550: 'Sleep bag padded',
#   176754: '2 Row Braided Headband (1)',
#   179123: 'Long Leggings (1)',
#   179208: 'Control Top 100 den 1p Tights',
#   179393: 'Basic 2p Overknee',
#   179950: 'Austin basic leather hip belt',
#   181160: 'Eva chelsea boot',
#   181448: 'Jenny 5-pack',
#   182909: 'Fleece 1 p tights',
#   183815: 'Bobby elastic waist belt',
#   184121: 'FIFTY SHADES moulded halternec',
#   184123: 'FIFTY SHADES  tie brief',
#   184583: 'Robin 3pk solid',
#   186262: '4p Claw',
#   186264: '10p Terry w.o. Clip',
#   186266: '10p Basic Terry',
#   186267: '12p Claw',
#   186372: 'Harem trousers',
#   186595: 'Lena over knee.',
#   187949: 'Padded pyjama',
#   188183: 'Spanx alot Swimsuit',
#   189383: 'BASIC LS TURTLE NECK BODY',
#   189616: 'Heavy jsy long leg',
#   189626: 'Jodi skirt',
#   189634: 'Long Leg Leggings',
#   189654: 'Raven skirt',
#   189691: 'Carolina sweater (1)',
#   189955: 'Nora tee',
#   190021: 'Basic 5p Minishaftless',
#   190252: 'Chris 3pk solid',
#   192460: 'Knit dress',
#   192960: 'Neo running beanie',
#   194037: 'Fleece leggings 1 p',
#   194242: 'HONEY L/L Leggings',
#   194270: 'HELENA 2-pack tanktop',
#   194902: 'BERTIL Basic 2-pack S/S SB',
#   198518: 'METS 2-p basic shorttop',
#   198714: 'Babette cropped',
#   199119: 'Basic shorts',
#   200182: '40 den 2p Tights',
#   200761: 'TORKEL tanktop SB 2-p',
#   201219: 'Heavy plain 2 p tights',
#   202017: 'Rihanna dress',
#   203027: 'Linni tee (1)',
#   203595: 'Bryn Flanel Check',
#   204892: 'Frode outdoor beanie',
#   205225: 'PICKUP ARTIST top',
#   211143: 'Janet SL-set (W)',
#   212042: 'Mimmi sneaker',
#   212629: 'Alcazar strap dress',
#   212766: 'Dean Drawstring Trousers.',
#   213690: 'H-terry Basic 16-pack',
#   213691: 'H-string Jersey',
#   214844: '30p pins',
#   215248: 'Bob v-neck tee',
#   215303: 'Coolio sunglasses',
#   215324: 'Classic Fancy pilot (1)',
#   215337: 'Pamela tee',
#   215589: 'Mama 40 den 2p Tights',
#   216081: 'Norling Knit',
#   216961: '4p Elastic Headband (1)',
#   217207: '2P SS PYJAMA',
#   217727: 'Polly 3p minishaftless',
#   218354: 'Beyonce cropped tank',
#   218829: 'Paris glove.',
#   219075: 'Billy cargo pants',
#   220094: 'Aguilera maxidress',
#   220365: 'Cool Olja round',
#   224314: 'Pinocchio hat',
#   224337: 'New Carrie Glove',
#   224521: 'DERRIDA windstopper tights',
#   224606: 'Flora hip belt (1)',
#   225286: 'Gauss windproof zip top',
#   225784: 'HARLEY 2-pack basic tee',
#   226011: 'Flirty Maria 2p Hawaii',
#   226959: 'Astaire 1p Overknee',
#   228257: '20 den 2p Tights',
#   233091: 'Magic Gloves 2pack',
#   233672: 'V-NECK LS SLIM',
#   234187: 'Paco solid flatpeak',
#   234421: 'Mama 200 den Tights',
#   234432: 'Push Up 30 den 1p Tights',
#   234622: 'RAF basic 2-pack rollerneck SB',
#   235596: 'Basic 4pk studs',
#   235732: 'Emma long-john PJ (K)',
#   237032: 'Fancy long Leg Leggings',
#   237222: 'Ingrid',
#   237347: 'Theron (1)',
#   238197: 'Lima l/s',
#   240561: 'Support 70 den 1p Tights',
#   240670: 'Tess tee (1)',
#   240840: 'BASIC JERSEY TIGHTS OC',
#   241412: 'AOP Leggings',
#   241436: 'Fix it tote bag',
#   241486: 'MILL blocking tights',
#   241590: 'Matt black SF regular fit blz',
#   241602: 'Manson SF slim fit blazer',
#   242354: 'CALVIN running shorts',
#   243613: 'Minna highwaist leggings (1)',
#   243937: 'Straight Edge 5p Socks',
#   244267: 'Silver lake',
#   244269: 'Basic Henley body',
#   244853: 'Basic Hood',
#   245348: 'Santa Hat',
#   247072: '2P SS Girly PJ',
#   249136: 'Skinny Ankel Denim',
#   250099: 'Mama Heavy Plain 2p Tights',
#   250457: 'Brandon denim cropped',
#   251510: 'Push up 70 den 1p Tights',
#   252229: 'Lory sweatpants (1)',
#   252298: 'Danae jeans',
#   253176: 'PICKUP ARTIST cheeky brief',
#   253448: 'OP Push Melbourne^',
#   254303: 'Bernard half calf socks',
#   254457: 'Basic SS dress',
#   254940: 'Elsa high waist',
#   255396: 'Nora Cardigan',
#   256096: 'Basic SS henley t-shirt',
#   256151: 'Superstretch Fancy denim',
#   256511: 'WIDEAWAKE triangle',
#   256513: 'WIDEAWAKE tie tanga',
#   257430: 'ROMY 2p',
#   257667: 'Lizzie',
#   258650: 'Berlin boot',
#   260736: 'NATE  basic S/S solid tee BB',
#   261526: 'ELLA 5-p shaftless',
#   261606: 'THALES tanktop',
#   261840: 'ELLA 5-p shaftless',
#   262277: 'Kim superskinny low waist',
#   264713: 'Al Car Shoe',
#   264984: 'Billie',
#   265069: 'PELLE Basic S/S jersey polo SB',
#   265071: 'KRISTOFF Basic jersey polo BB',
#   265630: 'Invisible 3p minishaftless',
#   266168: 'Shaper Shorts (1)',
#   266873: 'Micro 2p minishaftless',
#   266875: 'Sportsneaker 3p socks',
#   268305: 'Kattis cat sunglasses',
#   268450: 'LIAM 2-pack tanktop SB',
#   269342: 'Tina NT s/s',
#   270375: 'Sandra squared',
#   270381: 'Clubba sunglasses',
#   270382: 'Burnie sunglasses',
#   272591: 'Lena Rib Dress (1)',
#   275362: 'Jersey harem shorts',
#   276242: 'LS frill dress',
#   276540: 'PEP PJ 9.99',
#   277738: 'Basic overall',
#   278038: 'LORA',
#   278563: 'Harris cross sandal PQ',
#   278811: 'Hilly Biker 2pk HW LS',
#   280256: 'Mirage Push',
#   282832: 'Kevin softshell jacket (1)',
#   283236: 'Howie SS Shirt',
#   283532: 'Hanny Padded bra E&F',
#   283937: 'MASOLO PJ LONG LEG 14.99',
#   284985: 'BUDDY 2-pack L/S',
#   285143: 'HOLMES Sweat Trousers',
#   285602: 'SS body with collar',
#   286536: 'Layla Push',
#   287645: 'Microtights 2pk SG',
#   288575: 'Basic s/s henley body',
#   288825: 'Babsan 2-p tights',
#   288859: 'Kakan 2-p cableknit BG',
#   289597: 'UMBRELLA',
#   289834: 'FANTASTIC SHOPPER',
#   290022: 'Boris cap',
#   290519: 'Co/fl cardigan',
#   290675: 'Coyote padded vest',
#   291333: 'Keri 2pk tights SG',
#   291338: 'Pelin 2PACK tights',
#   291957: 'Chelsea welldressed trouser',
#   292453: 'Flirty Chantal earring',
#   292551: 'SOFIE BEANIE',
#   293244: '2-p micro tights BG',
#   293433: 'Basic 2PACK tights KG',
#   293510: 'Basic 2PACK tights YG',
#   294008: 'HM+ Cora tee',
#   294076: 'Skinny Shaping',
#   294237: 'Aurora winter cap',
#   294895: 'Rodney basic beanie',
#   295873: 'Sune leather glove',
#   296366: 'Flirty Fiffi flower headband',
#   296375: 'Flirty Fiffi 2p flower',
#   296471: 'TINA 7-P',
#   296476: 'DIVA ROBE',
#   297067: 'Small dot 1p Tights',
#   297078: 'Heavy Chain 1p Tights',
#   297791: 'Thigh High 1p Overknee',
#   297796: 'Spearmint shorts',
#   297898: 'Skinny high waist black',
#   299668: 'Sanne treggings (1)',
#   299733: 'Hilton',
#   299768: 'Peder knitted glove',
#   299841: 'Haakan',
#   300024: 'Superskinny',
#   300637: 'Fingerless knitted 2-pk',
#   300696: 'Glove Magic Touch Pack',
#   300907: 'Sean Biker',
#   300908: 'Freja Coat',
#   301213: 'Tilda clean padded bra (1)',
#   301227: '10pk regular',
#   301364: 'Ozzy',
#   301517: 'Cool Kajsa Headband',
#   301656: 'Shirtdress Lou',
#   301668: 'Elly tights',
#   301687: 'Lurex tights BG',
#   301901: 'Jenny Cardigan',
#   302311: 'Wales sweater',
#   302334: 'Sebastian braided belt',
#   304576: 'FORTUNA T-SHIRT',
#   304692: 'Mohair 2p Kneehigh',
#   304766: 'Mohair 2p Heavy Socks',
#   304778: 'Cosy 1p Lounge sock',
#   304786: 'Traditional 2p Heavy Socks',
#   304946: 'Leon',
#   305304: 'Boy Denim Shorts',
#   305305: 'Shaping Skinny R.W Ankle',
#   305584: 'Rose lace (1)',
#   305775: 'Lurex tights SG',
#   305931: 'Fake 1p Leggings',
#   306307: 'Lima ss',
#   306847: 'Honey Leggings 2PACK - TVP',
#   307239: 'Hilly Brief 2pk HW LS',
#   307656: 'Maria Shorts',
#   307847: 'Vibeke 2-p',
#   307952: 'Hype',
#   308154: 'LS Body with collar',
#   308158: 'LS body girly with collar',
#   309434: 'COSY ROBE',
#   309509: 'Peggy Padded jacket',
#   309864: 'Skinny Cheapo 89',
#   310091: '3P LS PJ feet w zip',
#   310365: 'RENEE REVERSABLE SCARF',
#   311059: 'BEN fancy crewneck SB',
#   312058: 'SS body girly with collar',
#   312543: 'Biker Leggings (1)',
#   312829: 'Cobra Tube.',
#   312878: 'Pablo coat',
#   315352: 'Edit dress (1)',
#   315497: 'Otto Beanie',
#   315509: 'Wolf Scarf',
#   315795: 'Braces Tweed 3-Clip',
#   315987: 'Pierre Beanie',
#   316008: 'Salinas Scarf',
#   316085: 'Peggy polo',
#   316242: 'Victoria (1)',
#   316441: 'Lee (1)',
#   316471: 'Klein',
#   316553: 'Washington dress',
#   316657: 'Karenina Jacket',
#   317055: 'Racer Tank Fancy License',
#   317348: 'Elvis jumper',
#   317812: 'LOLLY SKIRT (1)',
#   318035: 'Classic Clear umbrella',
#   318066: 'KIMBERLY Braided Headband',
#   318238: 'Braces Frank 3-Clip',
#   318914: 'Basic cotton fleece leggings',
#   318951: 'Basic LS t-shirt',
#   319811: 'Basic tanktop romper',
#   319906: 'Steve Slipper',
#   320524: 'Sergio Knitted Scarf',
#   320880: 'JOAN SUEDE BOOT',
#   321249: 'Xmas Bauble 1p Socks',
#   321591: 'Stefan Scarf',
#   322017: 'Mini Umbrella',
#   322322: 'Pelle Beanie',
#   323274: 'SIGGE LICENSE (1)',
#   324375: 'MARY KATE EARMUFFS',
#   324502: 'Hawlin Headband',
#   324946: 'Control Top 200 den 1p Tights',
#   324963: 'Classic PU sunglasscase',
#   325027: 'Irina Softbra 2pk',
#   325087: 'Kelly (Melbourne) PUSH 2p',
#   325542: 'Nina Nightshirt (W)',
#   326885: 'MAX jersey pants SB',
#   327144: 'Rally 2p tights',
#   327310: 'Alicia wrap skirt',
#   327368: 'HOLLY L/L leggings',
#   327821: 'MALAGA 2-P',
#   328480: 'Tech basic pants',
#   329052: 'ANDERS SP',
#   331062: 'Christmas pyjama (1)',
#   331072: 'Kobe Low Chelsea Boot',
#   331093: 'LEA jumpsuit',
#   331474: 'JOEL fancy sweatpant SB',
#   332055: 'Flirty Emma takeyaway mug',
#   333159: 'Glacier self warming tights',
#   333323: 'Basic rolltops 3PACK',
#   333353: 'Classic Fido dog sweater',
#   334077: 'Emmons self warming top',
#   335037: 'HM+ Hilly Biker 2pk',
#   335896: 'Salamander L/S',
#   335991: 'XMAS Deer aliceband',
#   336125: 'SOLID PONCHO',
#   336881: 'Cypress leather pants',
#   337777: 'Easy iron L/S shirt',
#   337991: 'Sigge Dressed Belt',
#   338016: 'Basic Rollerbuckle belt',
#   338400: 'Hilly Thong 2pk',
#   339252: 'Hat Fredrik Paper Straw',
#   340223: 'Flirty Jingle headband',
#   340546: 'PAUL R-NECK',
#   341129: 'Mama Support 70 den 1p Tights',
#   341186: 'Bare legs Support',
#   341242: 'Dave waistcoat',
#   341452: 'Venice molly padded softbra',
#   341782: 'RILEY T-SHIRT',
#   341909: 'REBECCA basic tanktop',
#   341917: 'Holly halloween hair clips',
#   342034: 'Indiana Solid Scarf',
#   342060: 'Heavy plain Overknee 1p Tights',
#   342345: '3P LS PJ',
#   342434: 'Beanie Jimmy Jersey',
#   342840: 'Flirty Christmas Calendar',
#   342954: 'ZORROW DETAILED',
#   343973: 'Sara 2-p legging w lace',
#   344534: 'Gwen',
#   344625: 'ELLEN Sunhat',
#   344627: 'BASIC Sunhat',
#   344905: 'Seamless Push-up Biker',
#   344956: 'Flirty Romi waterbottle',
#   345815: '2PACK Tanktop Body TVP',
#   345830: '2P Tanktop body girly',
#   345922: 'Erling Necktube',
#   346539: 'Pattern 5p Socks',
#   347182: 'Josh Webbing Belt',
#   347200: 'Bo Dressed Belt',
#   347975: '2PACK SS Body TVP',
#   347983: 'SS Body Mixed 2P',
#   348168: 'SKINNY Price 89 (1)',
#   348330: '2P Tanktop body Mixed',
#   348442: 'Gilberto top',
#   348657: 'Sofia Simple Choker',
#   348870: 'Mary Kate L/S',
#   348995: '3p fancy tanktop body',
#   349080: 'Block 1p Overknee',
#   349301: 'GLASSIG ESPADRILLE',
#   349669: 'Lenny braces',
#   350082: 'Hayes',
#   350135: 'Basic jersey pant 1x1rib',
#   350911: 'Bowtie Kalle',
#   351098: 'Wool Scarf Akira',
#   351182: 'Glove Suede',
#   351332: 'Marshall Lace up Top',
#   351462: 'LAZER RAZER bandeau',
#   351484: 'Lazer Razer Brief',
#   351771: 'Angela cheeky back',
#   351914: 'Fred Basic (1)',
#   351933: 'Kelly Lace Padded Idro 2p',
#   352811: 'Sara long (1)',
#   354041: 'Flirty New years Aliceband',
#   354246: 'Basic LS Raglan t-shirt',
#   354307: 'Akoni Flatshoe',
#   355062: 'HW Garbo mask',
#   355072: 'Anita Tank (1)',
#   355307: 'Moa tanktop',
#   355325: 'LUKE 2-pack L/S Rib BB',
#   355421: 'Colette dress',
#   355569: 'Nicky Long',
#   356004: 'ZORROW CLEAN',
#   356174: 'Space Treggings s5',
#   356289: 'JESSY SKIRT',
#   356438: 'Flirty Millie shell',
#   356693: 'Gigi fake suede p cap',
#   357130: 'MIMMI',
#   357751: 'Basic Endless hoop',
#   357792: 'Alessa cat sunglasses',
#   358254: 'Mandy shorts',
#   358383: 'Cap Eazy Suede Peak App',
#   358483: 'Stressan light knit jumper',
#   358753: 'Basic Ronaldo necklace',
#   359043: 'Basic cotton terry shorts',
#   359504: 'Viola trs (W)',
#   359804: 'SOFIE THIN BEANIE',
#   359909: 'Solid Paco',
#   360295: 'Kardashian shopper',
#   360859: 'Chelsea welldressed blazer',
#   360950: 'Sunglasses Edward',
#   361401: 'Chloe 3/4 AOP',
#   361467: 'Claire S/S',
#   361531: 'Sunglasses Raymond Aviator',
#   362219: 'Mama Support 30 den 1p Tights',
#   362931: 'WAFFLE L/S CTN basic',
#   362997: 'Miami tanktop',
#   364297: 'SWEATPANTS OC',
#   364409: 'SYBIL sleeping mask',
#   365025: 'Petra fancy shorttop 2p',
#   365058: 'Shorts-Sliq-Cut-Off-Bright-Na',
#   365102: 'Urban USB cable',
#   365439: 'Lawrence training sock',
#   365592: 'MIKKI SLIP ON SNEAKER',
#   366686: 'Tail tee',
#   366859: 'Reggie chino shorts',
#   367194: 'Mott glove',
#   367372: 'Mama 200 den Leggings',
#   367376: 'Black umbrella',
#   368038: 'Biq Square Claw',
#   368300: 'Rock Relaxed Shorts',
#   368505: 'Timon coat',
#   368603: 'ANTHEA pj (1)',
#   368979: 'ED Long leggings',
#   369423: 'Heart sunnies',
#   369796: 'John sunglasses',
#   370594: 'Saya sunglasses',
#   370737: 'Sunglasses Blixa CO',
#   370868: 'Virginie shorts 2p (K)',
#   372008: 'Halter',
#   372576: 'Robin 7pk Basic',
#   372628: 'Spencer Softbra 2pk',
#   372860: 'Basic 7p Shaftless',
#   373493: 'Everyday 5p shaftless',
#   373506: 'Trainer 3p sock',
#   373698: '3P tank PJ',
#   374762: 'Wilma dress (1)',
#   375248: 'LOVE 2-pack leggings',
#   375585: 'Sigge shorts',
#   375849: 'Penny 70s baseball',
#   375917: 'Hat Frank Fedora(1)',
#   376172: 'Karla sunglasses',
#   377239: 'Basic Loose Jerseypants',
#   377266: 'Sadie strap',
#   377277: 'Svea Cropped Tank',
#   377289: 'EASY PEASY swimsuit (1)',
#   377436: 'Flirty Real flower shell',
#   378124: 'L/S Polo Gnocci',
#   378135: 'R-Neck Pisa',
#   378447: 'V-Neck Milan TVP',
#   378719: 'Flirty Milkyway Eardeco (1)',
#   379360: 'MAXI 2 pack',
#   379780: 'Rita Ringer Tee',
#   379963: 'Mama plain cotton leggings 2p',
#   380193: 'Cameron Cut Off',
#   380609: 'Livia Top',
#   380894: 'Chlo̩ cosmetic bag',
#   381038: 'Cori cropped hood',
#   381187: 'Lottie Tee',
#   382127: 'Roman running hood',
#   382468: 'Backpack Oliver',
#   383152: 'Henric Superpush',
#   383569: 'SPEED Pavlova dress',
#   384263: 'Sonny Denim',
#   384482: 'Godfather SF Chino',
#   384654: 'Wanda Dress',
#   384851: 'Sage Shorts',
#   386399: '3P SS PJ',
#   386463: 'Cool Betty earring pk',
#   386678: 'Big Arjuna crossbag',
#   386681: 'Mini cross bag',
#   386695: 'Penny leather cross',
#   386859: 'Allington R-neck',
#   387348: 'Thales printed tanktop',
#   387426: 'Goodman light shorts',
#   387444: 'Petit cross bag (1)',
#   387843: 'Richie Regular Hood',
#   388573: 'Wera western belt',
#   388916: 'Washed Leather belt',
#   389236: 'Nate Anorak',
#   389388: 'Stef training gloves',
#   389479: 'Iwa Nightslip (J)',
#   389892: 'Poppy Poncho (1)',
#   390469: 'Meadow Push Bonny',
#   390512: 'Haddock Beanie',
#   390531: 'Sian Headband',
#   391032: 'Eazy Badge Cap',
#   391598: 'AZELIA IPHONE CASE',
#   391750: 'Manson trs',
#   391772: 'Matt regular trs',
#   392126: 'Claesson Leather Weekend',
#   392168: 'Lilly Twill Shorts',
#   392203: 'Vera backpack',
#   392220: 'Tie Mini Dot',
#   392269: 'CORBY TANK',
#   392820: 'Ralf Anchor Wrap Around',
#   392933: 'Ida Padded bra (1)',
#   392938: 'TD Hugo Stretch',
#   393321: 'Skeleton 1p tights',
#   393447: 'Leia Parka',
#   393750: 'Agnes polo',
#   393772: 'Sonny Pants.',
#   393993: 'Fuji jacket',
#   394292: 'Sunglasses Morris',
#   394522: 'TD Ulrik',
#   394798: 'S/S Hugo Stretch C/R',
#   394803: 'Asteria Tank',
#   395127: 'CA Gustavsberg slim fit TVP',
#   395575: 'Emily Brief',
#   395619: 'Malcolm Skinny 5 pocket',
#   395658: 'MIA (1)',
#   395730: 'VIOLA 2-pack (TVP)',
#   395864: 'RAKEL 3p',
#   396135: 'Glamping',
#   396690: 'Lincoln Itlay String Bracelet',
#   397068: 'Skinny L.W Bargain (1)',
#   397376: 'Elmer Elastic Belt',
#   397688: 'R.W Shorts Cut Off',
#   397807: 'Smoky padded ski pant',
#   398074: 'Sara 3/4',
#   398089: 'Shorts R.W Bargain',
#   398127: 'Shorts R.W Kelly',
#   398559: 'Molly T-shirt',
#   398814: 'Thomas tanktop',
#   398829: 'Shelly Wide Shorts',
#   398863: 'Wave shorts',
#   398947: 'Astrid round sunglasses',
#   398959: 'Stella sunglasses',
#   399036: 'Vera sweater',
#   399061: 'Jacket Slim',
#   399087: 'S.Skinny L.W Epic',
#   399136: 'Shaping Skinny R.W',
#   399201: 'Shaping Skinny H.W',
#   399223: 'Curvy Jeggings HW Ankle',
#   399256: 'Skinny Ankle R.W Brooklyn',
#   399589: 'Pocketknit',
#   400246: 'Feather Jegging L.W.',
#   400285: 'Straight R.W',
#   400296: 'Culotte',
#   400319: 'Boyfriend L.W.',
#   400342: 'Slim 5pkt Midprice',
#   400456: 'LS Body Solid 2PACK',
#   400489: 'Straight 5pkt',
#   400901: 'KNEE HIGH SOCK',
#   401020: 'Zip knit (1)',
#   401044: 'Cora Dress',
#   401136: 'Carla parka (1)',
#   401729: 'CHRISTINA BOOT',
#   401902: 'Go light jacket',
#   402065: 'TP OSCAR l/s tee SB',
#   402361: 'Smith light weight racerback',
#   402382: 'Icona Premium scarf',
#   402389: 'Icona premium beanie',
#   402595: 'Oskar glove',
#   403392: 'TOMMY basic sweatpants BB',
#   403421: 'THEO basic hood BB',
#   403448: 'GREG tanktop BB 2-p',
#   403479: 'BILLY s/s BB 2PACK',
#   403490: 'ELIAS basic 2-p V-neck BB',
#   403579: 'JONES l/s Henley BB',
#   403844: 'Montana pants',
#   403994: 'Vegas (W)',
#   404383: 'Butch hood',
#   404441: 'Lesly neck gaitor',
#   404609: 'Jerry singoalla top',
#   404864: 'Basic Cool Pants',
#   405310: 'Ciara sunglasses',
#   405586: 'Volly jumper (1)',
#   405635: 'Polly Jacket',
#   405636: 'JIMMY raglan l/s BB',
#   405676: 'Romeo push Melbourne',
#   405887: 'NORA',
#   406155: 'Pack Santa',
#   406160: 'Atlas',
#   406181: 'Newman dress',
#   406724: 'Sunglasses Hendrix',
#   406979: 'Corinne jumpsuit',
#   406987: 'Tony woven jumpsuit',
#   407031: 'Midge top',
#   407040: 'Daphne l/s',
#   407147: 'Adele LS',
#   407354: 'Jack jersey denim',
#   407653: 'Basic 9-pk studs',
#   407663: 'Class Jacob studpk',
#   407806: 'Class Ture bangle',
#   408045: 'Sickan Shopper',
#   408104: 'TD Roger',
#   408554: 'Rolled edge 3p Socks',
#   408569: 'Lurex 2p Sock',
#   408571: 'Tua 2p kneehigh',
#   408575: 'Papai 1p Overknee',
#   408647: 'Chenille 2p Lounge sock',
#   408649: 'Fun Chenille 2p Lounge sock',
#   408664: 'X-mas 2p Heavy Socks',
#   408875: 'Goldie tank top',
#   408884: 'Bracelet Bangle CO',
#   409683: 'Verona Tank',
#   409730: 'Granada tank',
#   409731: 'Cornell ss jumper',
#   410024: 'Mr Bomberton',
#   410291: 'HoneyMelon',
#   410424: 'STINA fancy',
#   410549: 'Riga PJ',
#   410624: 'Mitch top',
#   411013: 'Rut Jumper',
#   411413: 'Brooke raw cut ss',
#   411499: 'Emil (1)',
#   411565: 'Clear glasses Hendrix',
#   411569: 'Tie Basic Solid Conscious',
#   411758: 'Jonas slim 5 pkt',
#   411974: 'OL BLIXTEN PQ sneaker',
#   412031: 'Skinny denim 5 pkt panel',
#   412043: 'Basic didier 6-p',
#   412333: 'Houston SP Andes',
#   412370: 'Mama fleece leggings',
#   412579: 'Walker Knitted Tube',
#   412664: 'Olivier Knitted Scarf',
#   412707: 'Julia',
#   412869: 'Johan Wirstwarmer',
#   412964: 'Emma String (1)',
#   413029: 'Skinny Ankle H.W',
#   413599: 'Bowie Push Mirny',
#   413707: 'Fancy Leggings',
#   413763: 'Handrew Hunterglove',
#   413911: 'BEN basic crewneck SB',
#   413965: 'Herman cotton beanie',
#   414066: 'DENNIS onepiece SB',
#   414079: 'Fanny shorts',
#   414102: 'Mikael Glove',
#   414577: 'Manhattan shirt (1)',
#   416089: 'Bracelet Mixalot Pack CO',
#   416157: 'Bruce skinny 5-pkt',
#   416175: 'ALGOT 2-p tights',
#   416387: 'Ridley Leather Belt',
#   416511: 'Julia Denim Short TRS',
#   416905: 'Jaako Knitted Trapper',
#   416911: 'Ludlow Beanie (1)',
#   416961: 'Jade Denim Short TRS',
#   417088: 'Jacket Trucker',
#   417427: 'Cool Vesper watch',
#   417687: 'Smith Push',
#   417773: 'Star Wool Coat',
#   417855: 'Wyatt Window Buckle Belt',
#   417951: 'Support 20 den 1p tights',
#   418545: 'ALGOT 2-p body',
#   418662: 'Big Nick Beanie',
#   419634: 'Sonja Basic Thin Choker',
#   420049: 'OL TAGE PQ',
#   420264: 'Pack Bowtie Pin Pack',
#   420378: 'Leia lap top case',
#   420387: 'Harrison superpush',
#   420396: 'Harrison SP Body',
#   420963: 'Kiev pj',
#   421387: 'Isak graphic tee',
#   421941: 'Specter l/s tee',
#   422106: 'Hood W Zip',
#   422393: 'Nina classic flannel PJ',
#   422461: 'Jolly Box Brazilian 3pk',
#   423103: 'Basic jersey cardigan w. frill',
#   423112: 'W Enzo (1)',
#   423539: 'Pack Premium 2-Set',
#   423900: 'Gullan 5-p ankle sock SG',
#   424022: 'Annabel V neck',
#   424254: 'Chung woven dress',
#   424432: 'Merino 2p socks.',
#   424468: 'Furno Tights',
#   424470: 'Furno Top',
#   424511: 'Swift jumper',
#   425173: 'Eazy Anetti Cap',
#   425217: 'Leila sarong (1)',
#   425218: 'Hudson sarong',
#   425242: 'Vera LL PJ (J)',
#   425526: 'Dawn tee',
#   425529: 'Sleep bag velour',
#   425639: 'Luwin knit jumper',
#   425683: 'ALFONS 2-p cap',
#   425978: 'Cap Ben Baker Boy',
#   426013: 'Vintage Ankle H.W',
#   426019: 'Dungaree Alicia',
#   426199: 'Ellen Shortie Daisy Low 3p',
#   426541: 'Morgan Leggings',
#   426609: 'Fancy correy',
#   426674: 'Noora 5 pack Hipster',
#   427114: '2P LS Girly PJ with Frill',
#   427159: 'Skinny 5pkt Trash',
#   427558: 'Sagat Slim Blz',
#   427948: 'Winter PJ',
#   428071: 'Ophelia L/S',
#   428291: 'Tigra knitted headband',
#   428454: 'Omega bag',
#   429313: 'Charlotte SP Andes',
#   429314: 'Carla Brazilian Azalea Low',
#   429322: 'Charlotte SP N-Slip Andes',
#   430137: 'Straight H.W Ankle',
#   430157: 'MORRIS onepiece BB',
#   430596: 'Pack Black White',
#   430694: 'Skinny RW shaping',
#   430757: 'Cherry skirt',
#   431034: 'Pixies Leggings',
#   431570: 'Indiana Printed Scarf',
#   432566: 'Net 1p Tights',
#   432984: 'Diamanda',
#   433252: 'Beatle dress',
#   433275: 'MILLY onesie',
#   433414: 'NT Maria 2-pack',
#   433444: 'Sara s/s 2-pack',
#   433774: 'Flirty Scarlett earrings',
#   433796: 'FREJA 2-PACK',
#   434080: 'NET 2p socks',
#   434429: 'Mimi superstretch s5',
#   434773: 'ED denim jkt',
#   436083: 'Adhesive bra NEW',
#   436261: 'Control Top 30 den 1p Tights',
#   436570: 'Moscow Cross Bag',
#   436577: 'Shield Terry (1)',
#   436853: 'Diamanda tights BG',
#   437129: 'Zoey woven dress',
#   437150: 'Waterfall Winter coat',
#   437582: 'Halloween Skeleton Choker',
#   437668: 'Ethan',
#   437783: 'FOLKE funnelneck hoodie BB',
#   438147: 'Matilda sunglasses',
#   438333: 'Zoe Sweater',
#   438460: 'Class GP Flion necklace',
#   438499: 'Miracle velvet',
#   438702: 'LENA SNEAKER',
#   438953: 'Seamless biker body BIG FM',
#   439285: 'Stella treggings',
#   439646: 'June cut padding',
#   439793: 'Jordan',
#   439921: 'Louisa Stay Ups',
#   440144: 'Curtis Tee',
#   440811: 'Lydon Cardigan',
#   441386: 'Jonte Jogger (1)',
#   441536: 'Vero Tee Embellished',
#   442344: 'Holger Basic Tights (1)',
#   442345: 'Joel basic shorts',
#   442633: 'Tina NT l/s',
#   442786: 'Issa shorts',
#   442915: 'Dina',
#   442957: 'Charlie pull on top',
#   442992: 'Maserati dress',
#   443000: 'Gigi SP Andes',
#   443078: 'CA Berlin',
#   443262: 'Frank Tank',
#   443696: 'TP BO basic OH BB',
#   443860: 'Polo S/S Highline TVP',
#   444325: 'Tiffany dress',
#   444404: 'Elvis Skinny Blz',
#   445358: 'Glans tunic',
#   445400: 'Johan s/l pj BB',
#   445419: 'Leon tee',
#   445865: 'Dungaree Dress',
#   445901: 'Halo Half Zip',
#   446147: 'Wallace 2in1 Tee XS-L',
#   446155: 'Lea Shopper',
#   446224: 'Maja Cardigan',
#   446367: 'Kia Wallet',
#   446847: 'Taylor ripped jeans',
#   447201: 'Werter shaftless SB 5-p',
#   447264: 'Werter shaftless BB 5-p',
#   447596: 'Sindy round s-glass',
#   447664: 'Bea padded bra E&F',
#   447681: 'Trash trucker',
#   447692: 'Petar Sweater (1)',
#   447694: 'Benny Shorts (1)',
#   447795: 'Cloud runner',
#   448262: 'Roll up tee (1)',
#   448509: 'Perrie Slim Mom Denim TRS',
#   448515: 'Kendall RW Denim TRS',
#   448831: 'Tom Solid',
#   449099: 'HAL SHORTS',
#   449123: 'Correy tee',
#   449175: 'HANA Lace Bikini',
#   449192: 'ROBYN SWIMSUIT',
#   449263: 'Zero Tee',
#   449555: 'TERMINATOR FANCY TIGHTS',
#   449570: 'CLAY TEE',
#   449648: 'AMY FANCY Swimsuit',
#   449744: 'Karin Medium Support Bra',
#   449897: 'Slim 5pkt',
#   450056: 'SUPREME cropped',
#   450333: 'Hat Flynn Straw',
#   450604: 'Kay Nightshirt (W)',
#   450662: 'Dungaree Shorts',
#   450780: 'Washed Hoodie',
#   450932: 'Canasta joggers',
#   451019: 'PABLO POPOVER SHIRT',
#   451209: 'Flirty Elof studs',
#   451229: 'Skinny 5pkt Malcolm',
#   451243: 'Rufus 5-pkt trousers',
#   451271: 'Oliver chinos',
#   451286: 'Bull blazer',
#   451290: 'Oz SF skinny fit blazer',
#   451294: 'Rex blazer',
#   451380: 'Bruce denim',
#   451402: 'Bull trousers',
#   451541: '2 PK V-N SS SLIM FIT',
#   451556: 'Binet graphic LS tee',
#   451599: 'Olivier Necktube',
#   451650: 'Beatrice LS body',
#   451704: 'Gary suede micro tote',
#   451720: 'George Beanie',
#   451744: 'Joel straw shopper',
#   451774: 'Big Sarah Cross Bag',
#   452486: 'SABILLA 3 PACK',
#   452511: 'Class Amelie necklace',
#   452516: 'Oz trousers',
#   452616: 'SIVAN 2 PACK',
#   452618: 'Clean Edge 60 den 1p Leggings',
#   452717: 'Corsica',
#   452818: '5pk regular basic',
#   452851: 'Marie 7-p sock BG',
#   452898: 'MARION-SHORTS',
#   453016: 'Polly shorts',
#   453026: 'Perfect tee',
#   453028: 'Chiara hood (1)',
#   453065: 'Eivor 7-p shaftless',
#   453134: 'NELLY 2 PACK S/L',
#   453239: 'TVP Slim denim',
#   453258: 'Chuck Denim jkt (1)',
#   453272: 'SB TRUNKS',
#   453309: 'SB JAKE basic board shorts',
#   453345: 'Ringo hip belt',
#   453358: 'Dalia hip belt',
#   453445: 'BB ASTON',
#   453453: 'BB ASTON PRICEshorts',
#   453491: 'Essential: Rex',
#   453585: 'Sassy 3-pack hip belt',
#   453741: 'HILDA PLATFORM',
#   453745: 'ASHTON (1)',
#   453765: 'Capri cardigan',
#   453828: 'BOBBY CUTOUT',
#   453831: 'MAIKEN LACE-UP',
#   453988: 'Eva Tank Top (1)',
#   454008: 'Sheffield woven dress',
#   454128: 'ANTHEA 2-p PJ',
#   454143: 'Ada woven dress',
#   454196: 'Speedy Tee (1)',
#   454199: 'Jackie coat',
#   454544: 'California Jogger',
#   454602: 'Alfie knit jumper (1)',
#   454804: 'Jogger Wilson 79',
#   455014: 'Marie 7-p ankle sock',
#   455491: 'Spearmint shorts',
#   455504: 'D-SUIT ESTELLE BASIC',
#   455828: 'Kendall skirt ED',
#   455832: 'Charlotte Soft  Body',
#   455925: 'Yates LS tee',
#   456007: 'Mia playsuit',
#   456011: 'HW shorts',
#   456032: 'Relax Shorts (1)',
#   456163: 'Woody(1)',
#   456245: 'Chelsea welldressed waistcoat',
#   456634: 'Jesper tee',
#   456641: 'Clarence Hipster Poppy Mid',
#   456834: 'Emma basic SG',
#   457039: 'Bernie top ED',
#   457059: 'Halie top',
#   457079: 'Rachel dress',
#   457135: 'Moss PU biker',
#   457292: 'Cherry dress',
#   457314: 'Vickan frill dress (1)',
#   457322: 'SB UV Shirt LS',
#   457412: 'Denise shirt',
#   457466: 'Control Top 15 den 1p Tights',
#   457491: 'Derrida Hi-Vis tights',
#   457618: 'Sheffield shirt',
#   457722: 'Axel fancy denim shorts',
#   457755: 'BB UV Raglan',
#   457765: 'Viveka 5-p shaftless SG',
#   457892: 'Fox (1)',
#   458032: 'WILDER',
#   458064: 'Nils running pant',
#   458083: 'BELT LEATHER',
#   458087: 'Fia longsleeve (1)',
#   458239: 'Tess',
#   458393: 'Serena Tank 2PACK',
#   458428: 'Cobra Constructed',
#   458543: 'Lazer Razer Push Up',
#   458851: 'Poppy cotton shirt',
#   458882: 'Gardenia Shirt (1)',
#   458924: 'Pablo round neck',
#   458925: 'Javier',
#   459144: 'Vermont fancy',
#   459149: 'Hepburn strap top',
#   459307: 'Hat Filly Straw',
#   459428: 'Jerry Hood',
#   459617: 'Lo Tunic',
#   459756: 'CLEO HIGHLIFT SNEAKER (1)',
#   460302: 'Amiga',
#   460363: 'Sivert sneaker',
#   460891: 'Sabini woven dress',
#   461327: 'Rollerneck Charlie TVP',
#   461414: 'OL LINUS PQ loafer',
#   462086: 'Steph SL Set',
#   462128: 'LS PJ',
#   462162: 'Relaxed Skinny 5pkt',
#   462435: '6P Tanktop Body',
#   463086: 'Eve dress eller annan',
#   463117: 'Rick Suede Cap',
#   463285: 'Kelly',
#   463290: 'Angelica',
#   463536: 'Harry Superpush',
#   463601: 'TUNIS ls 2p (1)',
#   463670: 'Caramella',
#   463970: 'Greta Hipster Ch. (Poppy) L 3p',
#   464277: 'Greta Shortie (Daisy Mid) 3p',
#   464297: 'Greta Thong Mynta Low 3p',
#   464332: 'Zola wide sleeve sweat',
#   464363: 'Camille tee (1)',
#   464454: 'TANJA SKIRT',
#   464541: 'Envy lace',
#   464566: 'Ylva hipster 3pk',
#   464610: 'Bo Reversible',
#   464679: 'HM+ Kim 2p padded',
#   464695: 'ROMY 3-p tanktop',
#   464848: 'Cindy N-slip (K)',
#   464908: 'Liza Thong Low (Malva) 3pk',
#   464927: 'Ivory Ch. braz. Low Acacia 3pk',
#   465051: 'Sandy off shoulder',
#   465572: 'THEA set',
#   465619: 'RICK l/s henley SB',
#   465655: 'Ginger Thong Maple Low 3p',
#   465816: 'Ring Pack Jose',
#   465862: 'Necklace Donnelly',
#   466006: 'Flirty Bowie Waterbottle',
#   466381: 'Greenville bra (1)',
#   466579: 'Nova Denim 5-pkt',
#   466595: 'Rawley Chinos Slim',
#   466599: 'Wave linen',
#   466666: 'Emmy 2-Pack Body',
#   466852: 'Tommy tights',
#   466891: 'City shorts',
#   466917: 'Falkon',
#   466948: 'LOGAN l/s raglan SB',
#   466987: 'Kurt Check',
#   467174: 'MAZER GLAZER top',
#   467191: 'Bobby cotton',
#   467297: 'Ole Cargo',
#   467302: 'Panda dress J',
#   467557: 'Africa velvet skirt',
#   467738: 'Aiden Belt',
#   468013: 'Sherpa cardigan',
#   468255: 'Ariana dress SPEED',
#   468345: 'PETER SLIM FIT POLO',
#   468480: 'Vintage H.W Shorts',
#   468591: 'August s/s snug fit pj 2-p',
#   468666: 'SANNA BIKINI BOTTOM',
#   468695: 'Perrie Denim Shorts',
#   468977: 'Selena Shopper',
#   469001: 'Daniel scarf',
#   469021: 'Harry Herringbone',
#   469039: 'Henrik ballerina',
#   469137: 'Juan lace strap top',
#   469271: 'Raven Scarf',
#   469562: 'Skinny denim (1)',
#   469649: 'Kosmos',
#   469658: 'Spice Girl 3pk hipster',
#   469682: 'Dolores (1)',
#   470111: 'MC Gyda blouse',
#   470167: 'Scarf Coski Conscious',
#   470361: 'Hat Karl Paper Straw',
#   470478: 'MC Hayes trs',
#   470636: 'Ivy jumpsuit W',
#   470766: 'Majken Maxi Dress',
#   470789: 'OP Brazilian 2p Low (Acacia)',
#   470985: 'Vaughan sneaker',
#   471074: '2p OP Shortie Medium (Daisy)',
#   471077: 'Charlotte Suspenderbelt',
#   471456: 'Eclipse blouse',
#   471566: 'OL STAFFAN PQ loafer',
#   471641: 'Li Highwaist brief 2pk',
#   471714: 'Roy Shorts',
#   472064: '6P LS bodypack',
#   472065: 'Novak Ruffle Tank',
#   472243: 'Pollock cap',
#   472320: 'Slash Tee',
#   472341: 'Twist Dress',
#   472447: 'Crawl Tank',
#   472755: 'Ben runner gloves',
#   472844: 'Cool Smarty sunglasses',
#   473034: 'ALGOT S/S 2-p body',
#   473497: 'Zoella suede shopper',
#   473507: 'Lindsay shopper SPEED',
#   ...}}

# %% [markdown]
# #### Finding names having multiple codes each and replacing with single code

# %%
def find_duplicate_value(col_dict):
    y=pd.array([str(x) for x in col_dict.values()]).value_counts()
    y=y[y.values>1]
    return y.index

# %%
def get_duplicate_value_keys(col,col_dict):
    name=find_duplicate_value(col_dict)
    name_dict={}
    for i in name:
        codes=[x for x in col_dict.keys() if col_dict[x]==i]
#         print( i,":",codes)
        name_dict[i]=codes
        
    return name_dict

# %%
dup_section_dict=get_duplicate_value_keys(df_articles.section_name,section)
print(dup_section_dict)
print("---------------------------------------------------------------------------------------------------------")
dup_prodtype_dict=get_duplicate_value_keys(df_articles.product_type_name,product_type)
print(dup_prodtype_dict)
print("---------------------------------------------------------------------------------------------------------")
dup_dept_dict=get_duplicate_value_keys(df_articles.department_name,department)
print(dup_dept_dict)
print("---------------------------------------------------------------------------------------------------------")
dup_prod_dict=get_duplicate_value_keys(df_articles.prod_name,product)
print(dup_prod_dict)
# Out:
# {'Ladies Other': [4, 17]}
# ---------------------------------------------------------------------------------------------------------
# {'Umbrella': [83, 532]}
# ---------------------------------------------------------------------------------------------------------
# {'Knitwear': [1610, 1616, 1626, 1648, 1949, 2034, 5831, 5858, 5878, 5884, 7520], 'Trouser': [1710, 1717, 1722, 5631, 5656, 5683, 5686], 'Jersey': [1641, 1660, 1666, 1919, 2032], 'Shorts': [1723, 1745, 5658, 5687, 5690], 'Accessories': [3510, 3941, 7530, 9985], 'Shirt': [5731, 5767, 5777, 5783], 'Blouse': [1510, 1515, 1522], 'Jersey Fancy': [5828, 5848, 5882], 'Dress': [1310, 1313, 1322], 'Skirt': [1414, 1422], 'Woven bottoms': [1939, 2031], 'Small Accessories': [3946, 9986], 'Jersey License': [1670, 7952], 'OL Extended Sizes': [1774, 1778], 'Swimwear': [4242, 9984], 'Blazer': [5131, 5555], 'Bags': [3209, 3944], 'Outwear': [1201, 1929], 'Belts': [3509, 7389], 'Loungewear': [3708, 9989], 'EQ & Special Collections': [3439, 4342], 'Jersey Basic': [1676, 5883]}
# ---------------------------------------------------------------------------------------------------------
# {'Bowie': [565737, 675827, 684151, 725234, 740564, 788176, 817491, 874587], 'Molly dress': [567837, 595218, 696989, 708487, 733814, 820960, 866587, 879294], 'Bella dress': [585724, 587191, 677811, 732844, 810547, 816594, 887827], 'Sandy': [562637, 651464, 710194, 740958, 765657, 786307, 893141], 'Dolly dress': [652057, 697045, 736033, 778534, 829054, 880367, 887829], 'Melrose': [675068, 735404, 744893, 751998, 821336, 842607, 873679], 'Lauren': [507676, 555684, 607627, 613457, 715903, 793911, 814766], 'SKINNY LINED': [685770, 685810, 688676, 688701, 738184, 747533, 751506], 'Daisy': [537461, 662868, 693956, 823789, 855076, 865374], 'Rose': [523950, 607295, 615523, 668562, 685429, 852535], 'Fiona': [539869, 552229, 652631, 711188, 767571, 861847], 'Spinach vest': [556360, 616131, 694813, 734927, 864043, 882021], 'Elsa': [568862, 658926, 684036, 687106, 803647, 894353], 'Jonna beanie': [519293, 574804, 647082, 691996, 759974, 824487], 'JANET blanket scarf': [584710, 646915, 650515, 697635, 740512, 806299], 'Siri beanie': [520963, 578960, 643628, 698726, 760048, 824748], 'SW Ariel swimsuit': [549720, 636500, 686318, 739541, 798288, 893971], 'Ruby': [523657, 618982, 667509, 724324, 831008, 876053], 'Kylie dress': [583801, 660273, 718489, 739688, 869598, 876331], 'PLATON set': [565241, 627456, 740065, 754108, 829361], 'Moa': [606115, 645090, 708714, 727347, 797164], 'Penny': [555667, 636904, 667534, 734316, 881267], 'Ariel': [596862, 605985, 611039, 684144, 878510], 'Presley PU skirt': [653321, 757378, 760056, 868319, 883951], 'Rose dress': [552212, 673917, 829601, 892278, 920394], 'Detroit skirt': [520457, 549393, 611146, 798471, 860617], 'Polly dress': [599102, 684613, 743471, 759636, 876372], 'Lip balm unicorn': [505573, 674959, 742731, 800333, 857713], 'Bella': [583733, 644200, 761821, 824310, 909831], 'Peony dress': [744535, 802027, 872771, 903850, 911521], 'Didier fancy 3p': [583131, 632462, 702605, 753213, 825509], 'Otto sandal': [617288, 700972, 735389, 808718, 887882], 'Rainbow dress': [676763, 696937, 806201, 870528, 897689], 'Sunglasses Gwen': [566288, 640726, 722923, 747276, 818021], 'Dragonfly dress': [677885, 690950, 739659, 804824, 870530], 'STRAW HAT': [562167, 625149, 694662, 694751, 816250], 'JOAN cap': [500815, 645485, 695801, 763157, 886039], 'KEN overall': [511242, 575373, 642651, 701754, 764358], 'Jing beanie 2p': [632459, 713445, 765879, 825748, 862627], 'Hannah basic ballerina SG': [556493, 623370, 679011, 733739, 813094], 'DANTE set': [494935, 551413, 624445, 694297, 750476], 'STURE overall': [494938, 642720, 694299, 764356, 919481], 'Underwater glasses': [626936, 636121, 728495, 771925, 850749], 'Moccasin': [587084, 695302, 759831, 810971, 868841], 'Billie': [264984, 561445, 607541, 670435, 702495], 'Sasha dress': [559807, 706068, 764551, 805380, 867111], 'Olivia dress': [504825, 618399, 670655, 778848, 871308], 'Cora': [637935, 728185, 755440, 800688, 879176], 'Barza': [489838, 510074, 606107, 857716], 'Kibble shorts': [583785, 646787, 697096, 876323], 'Lowe basic peak cap': [565430, 632456, 699003, 825772], 'Dolly slacks': [596740, 693574, 745294, 797313], 'AVIATORS': [618699, 625146, 694669, 694748], 'Bonnie': [578997, 612345, 684040, 764084], 'Sienna dress': [526127, 594215, 851309, 897693], 'Ellen shorts': [558979, 693575, 762740, 796785], 'TANJA SKIRT': [464454, 681381, 877607, 884920], 'Mini Meadow Denim': [548138, 633378, 698009, 760730], 'Molly': [557485, 562997, 677049, 759068], 'Valentina': [536385, 639573, 654353, 850549], 'Terry socks 3p': [518129, 587932, 695278, 751793], 'BACKPACK OWN': [625472, 630812, 755093, 897775], 'BASIC HOOD': [520496, 564048, 648738, 686997], 'JOHN bootie': [500825, 645486, 701686, 770237], 'Elva Dress': [577507, 681108, 742525, 801843], 'H-string mini elastic': [705779, 743165, 809075, 872865], 'Tomo dress': [559176, 737794, 833470, 908280], 'Doris ballerina': [569940, 700832, 745338, 888759], 'Evelina Dress': [591718, 642929, 699930, 811215], 'Milk': [664485, 68541 ...

# %%
def replace_duplicate_codes(df,name_col,code_col,dup_dict):

    for i in range(df.shape[0]):
            if(df[name_col][i] in dup_dict.keys()):
                df[code_col][i]=dup_dict[df[name_col][i]][0]
    return df

# %%
df_articles=replace_duplicate_codes(df_articles,'section_name','section_no',dup_section_dict)
df_articles=replace_duplicate_codes(df_articles,'product_type_name','product_type_no',dup_prodtype_dict)
df_articles=replace_duplicate_codes(df_articles,'department_name','department_no',dup_dept_dict)
df_articles=replace_duplicate_codes(df_articles,'prod_name','product_code',dup_prod_dict)

# %%
df_articles[df_articles.section_name=='Ladies Other']['section_no'].values
# Out:
# array([4, 4, 4, 4], dtype=int64)

# %%
df_articles[df_articles.product_type_name=='Umbrella']['product_type_no'].values
# Out:
# array([83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83,
#        83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83, 83], dtype=int64)

# %%
df_articles[df_articles.department_name=='Knitwear']['department_no'].values
# Out:
# array([1610, 1610, 1610, ..., 1610, 1610, 1610], dtype=int64)

# %%
df_articles[df_articles.prod_name=='Molly dress']['product_code'].values
# Out:
# array([567837, 567837, 567837, 567837, 567837, 567837, 567837, 567837,
#        567837, 567837, 567837, 567837, 567837, 567837, 567837, 567837,
#        567837, 567837, 567837, 567837, 567837, 567837, 567837, 567837],
#       dtype=int64)

# %% [markdown]
# #### The number of names and codes match for section, product type and department, but there is difference in product name and code. This means that there are some codes which are assigned to more than one name

# %%
df_articles.nunique().sort_values()
# Out:
# index_group_no                       5
# index_group_name                     5
# perceived_colour_value_id            8
# perceived_colour_value_name          8
# index_name                          10
# index_code                          10
# product_group_name                  19
# perceived_colour_master_name        20
# perceived_colour_master_id          20
# garment_group_name                  21
# garment_group_no                    21
# graphical_appearance_name           30
# graphical_appearance_no             30
# colour_group_name                   50
# colour_group_code                   50
# section_name                        56
# section_no                          56
# product_type_name                  131
# product_type_no                    131
# department_no                      250
# department_name                    250
# detail_desc                      43404
# product_code                     43664
# prod_name                        45875
# article_id                      105542
# dtype: int64

# %% [markdown]
# #### Finding missing product names from the dictionary

# %%
missing_prod_name=[]
for i in df_articles.prod_name.unique():
    if i not in product.values():
        missing_prod_name.append(i)
        
missing_prod_name
# Out:
# ['Strap top',
#  'Tanktop body white 3PACK',
#  'Connor pants',
#  'Sneaker 3p Socks',
#  'Long Leggings',
#  'Spanx alot shape Swimsuit',
#  'SPANX ALOT swimsuit (1)',
#  'Tina leggings',
#  'METS 2-p shorttop',
#  'TORKEL Basic 2-pack tanktop SB',
#  'Janet SL (W)',
#  'Olja sunglasses',
#  'Flora hip belt',
#  'Cap Paco Solid CO',
#  'RAF basic rollerneck SB 2-p',
#  'Helsinki',
#  'Theron',
#  'Didi denim',
#  'Flirty Kattis Cat (1)',
#  'Classic Clubba',
#  'Dress LS Basic',
#  'Hilly Biker 2pk LT',
#  'Kevin softshell jacket',
#  '2-p micro tights SG',
#  '2-p Babsan tights BG',
#  'Babsan 2-p tights BG',
#  'Kakan 2PACK tights BG',
#  'Basic co/fl cardigan',
#  '2-p Keri',
#  '2-p Keri tights SG',
#  'Keri 2PACK tights SG',
#  '2-p Pelin pointelle',
#  '2-p Pelin pointelle SG',
#  'Pelin 2pk pointelle tights',
#  'Micro 2pk tights BG',
#  '2-p microtights BG',
#  '2-p basic cotton tights SG',
#  'Basic 2pk tights SG',
#  'Basic 2PACK tights SG',
#  '2-p basic cotton tights BG',
#  '2-p basic cotton tghts',
#  '2-p basic tights BG',
#  'Basic 2PACK tights BG',
#  'Cora T-shirt',
#  'Glove Sune Leather',
#  'Super skinny denim',
#  '10pk basic R socks',
#  'Lou Shirt Dress',
#  'Lurex tights Bg',
#  'HONEY 2-P LEGGINGS',
#  'Honey Leggings 2PACK (TVP)',
#  'HONEY 2-P LEGGINGS (T VP)',
#  'Hilly Brief 2pk LT',
#  'COSY COTTON FLEECE ROBE',
#  'Skinny Cheapo 89 (1)',
#  '3P LS PJ with feet',
#  '3PACK LS PJ feet w zip',
#  'Lee',
#  'Beanie Pelle wool mix',
#  'TP MAX jersey pants SB',
#  'Kobe boot',
#  'JOEL Fancy sweatpants SB',
#  'TP JOEL fancy sweatpant SB',
#  'Basic rolltops 3-pack',
#  'Basic rolltops',
#  'XMAS Fido dog sweater',
#  'Easy iron L/S shirt  TP',
#  'Easy iron l/s shirt',
#  'Easy iron L/S shirt TP',
#  'TP Easy iron L/S shirt',
#  'NEW Sigge dressed belt',
#  'NEW Basic Rollerbuckle',
#  'Tanktop body Girly 2-pack',
#  '2PACK Tanktop body girly',
#  'Tanktop body Mixed 2p',
#  '2PACK Tanktop body Mixed',
#  'LAZER RAZER brief',
#  'LAZER RAZER brief (1)',
#  'Jessy skirt',
#  'Cool Alessa Cat',
#  'Raymond aviator',
#  'Sybil sleeping mask',
#  'Tail tee (1)',
#  'Reggie solid chino shorts',
#  'ROCK SHORTS',
#  'ANTHEA pj',
#  'Cool Metal John Round',
#  '7p Basic Shaftless',
#  'LOVE 2-pack lace leggings',
#  'Love leggings 2PACK',
#  'Love leggings 2PACK-superspeed',
#  'L/S Polo Gnocci TVP',
#  'R-Neck Merino Pisa',
#  'R-Neck Pisa TVP R',
#  'V-Neck Milan',
#  'V-Neck Merino Milan',
#  'MAXI 2PACK',
#  'Godfather slim chino',
#  'Wanda Dress (1)',
#  'Mini Cross Bag',
#  'R-neck Allington',
#  'T-Shirt Allington R-neck',
#  'T-Shirt Allington R-neck!',
#  'Cap Eazy Badge',
#  'TD Hugo slim fit Stretch PQ',
#  'TD Hugo Stretch PQ',
#  'CA Gustavsberg TVP',
#  'CA Gustavsberg',
#  'MUMS',
#  'MUMS (1)',
#  'VIOLA 2-pack',
#  'VIOLA 2PACK',
#  'RAKEL 3p boxer',
#  'Bracelet Lincoln CO',
#  'Jacket Slim (1)',
#  'Super Skinny L.W Epic',
#  'Shaping Skinny R.W.',
#  'Skinny Shaping R.W',
#  'Skinny Shaping H.W',
#  'Jeggings H.W',
#  'Feather Jeggings L.W',
#  'CHRISTINA BOOT (1)',
#  'OSCAR l/s tee SB',
#  'GREG 2-p tanktop BB',
#  'TP BILLY Basic 2-p S/S r n BB',
#  'BILLY Basic 2-p S/S r n BB',
#  'ELIAS basic V-neck BB 2-p',
#  'Vegas Shorts',
#  'JIMMY raglan tshirt BB',
#  'TD Roger eller TD Poplin 29 by',
#  'Bangle Bracelet',
#  'Emil Derby Shoe',
#  'TP BEN basic crewneck SB',
#  'Bruce skinny',
#  'Julia Denim Petite Trs',
#  'Jade Denim Petite Trs',
#  'Long Trucker Jacket',
#  'Classic Vesper watch',
#  'Harrison SP Andes',
#  'Gullan 5-p ankle sock',
#  'Gullan 5-p SG',
#  'Vintage cropped H.W',
#  'Morgan Price',
#  '2P LS GIRLY PJ',
#  '2P LS GIRLY PJ TVP',
#  'Skinny 5pkt Premiumprice 1',
#  'Sagat slim',
#  'Net Tight',
#  'Diamanda tights SG',
#  'MILLY Onesie pj',
#  'MILLY onesie SG',
#  'Maria NT 2-pack',
#  'Adhesive Bra',
#  'Moscow cross bag',
#  'Diamanda BG',
#  'Cool Matilda sunglasses',
#  'Stella treggings (1)',
#  'Jonte Skinny Jogger 24.99:-',
#  'Jonte Slim Jogger 24.99:-',
#  'BO basic OH BB',
#  'DENZEL basic OH BB',
#  'Polo S/S Highline',
#  'S/S Polo Highline',
#  'Johan s/l pj BB (1)',
#  'Werter 5-p shaftless SB',
#  'Werter 5-p shaftless BB',
#  'Roll up tee',
#  'Perrie Plain Denim TRS',
#  'Kendall Trash',
#  'Kendall Denim TRS',
#  'HAL SHORTS.',
#  'Zero Tee (1)',
#  'Washed Hoodie (1)',
#  'Oz blazer',
#  '5pk basic R socks',
#  '5pk regular',
#  'Marie 7-p sock',
#  'Marie 7PACK socks BG',
#  'SLIM FIT: BASIC',
#  'BB ASTON PRICEshorts Curved',
#  'ASHTON',
#  'ANTHEA 2P PJ',
#  'California Jogger (1)',
#  'Marie 7-p SG',
#  'Woody (1)',
#  'Woody',
#  'Woody hoodie',
#  'Axel fancy denim shorts (1)',
#  'Viveka 5-p rib shaftless',
#  'BELT BASIC',
#  'LEATHER BELT',
#  'Tess CN Unique',
#  'SERENA 2p tank',
#  'SERENA 2p tank (1)',
#  'Cobra Constructed (1)',
#  'LAZER RAZER push up',
#  'Gardenia Shirt',
#  'Rollerneck Charlie',
#  '6P Tanktopbody pack',
#  '6PACK Tanktop Body',
#  'Kim 2p padded BIG',
#  'Kim 2p padded E&F',
#  'HM+ Kim 2p Padded Bra',
#  'ROMY 3PACK tanktop',
#  'ROMY 3p tanktop',
#  'Rawley chinos',
#  'LOGAN l/s raglan',
#  'Panda dress',
#  'Mom Shorts',
#  'August s/s 2-p snug fit pj',
#  'Skinny denim',
#  'Coski Conscious Scarf',
#  '2p OP Brazilian Low (Acacia)',
#  'Crawl Printed Tank',
#  'Lindsay shopper',
#  '2p OP Hipster Cheeky Low',
#  'Challe biker',
#  'Satin Chiffon Kimono (W)',
#  'Evert Slim Shorts',
#  'Evert Shorts',
#  'Jones 5-pkt Slim Shorts',
#  'Pontus Espadrill',
#  'Madeleine cropped',
#  'Trisha tee dress(1)',
#  'Emma 3-p terry/chenille',
#  'Eagel PU Pants',
#  'Flirty Maja earrings',
#  'Jones Denim',
#  'Wave Shorts',
#  'NIKE FANCY',
#  'Signe 5 pack',
#  'DORIS SANDAL',
#  'SIVAN SEAMLESS',
#  'SIVAN SEAMLESS (1)',
#  'SIVAN 2-P seamless shorttop',
#  'Tiernan',
#  'Joe s/l pj in rib BB',
#  'Jacket Core',
#  'Isaac denim',
#  'Perfect Denim',
#  'Planck Leather Watch',
#  'Classic pilot clear glasses',
#  'Valter pj SB',
#  'Pricebrief 5-p brief SB',
#  'Silas s/l pj SB (1)',
#  'TP Felix pj SB',
#  'FELIX L/L PJ SB',
#  'Adam 2-p Long J SB',
#  'TP Adam 2-p Long J SB',
#  'Trosa onezie SB (1)',
#  'Lenny velour SB',
#  'Nils x-mas pj SB',
#  'Cole cotton blouse',
#  'Henrik 3-p boxer BB',
#  'Sixten fancy 3-p boxer BB',
#  'Kurt 5-p brief BB',
#  'TP Bobby l/l pj BB',
#  'TP Adam 2-p long john BB',
#  'Agaton 2-p long john BB',
#  'TP Agaton 2-p long john BB',
#  'Agaton 2-p Long J BB 2-p',
#  'Levis x-mas pj BB',
#  'Jackie brief 2pk HR LS',
#  '5-pack AXEL anklesock SB',
#  'Axel 5-p anklesock SB',
#  '7-pack LUCAS anklesock SB',
#  'TP Lucas 7-p anklesock SB',
#  '7-pack WEEKDAY anklesock SB',
#  'TP Weekday 7-p anklesock SB',
#  'Weekday 7-p anklesock SB',
#  'TP Stellan 7-p shaftless SB',
#  '7-pack STELLAN shaftless SB',
#  'Stellan 7-p shaftless SB',
#  '5-pack ANTISLIP anklesock SB',
#  'Anton 5-p antislip  SB',
#  'Jonas 2-p tights SB',
#  '5-pack BOB SPORT shaftless SB',
#  'Bob sport 5-p midshaft SB',
#  'Super soft',
#  'Sleep Bag Thin',
#  '5-pack AXEL anklesock BB',
#  'Axel 5-p anklesock BB',
#  'TP Stellan 7-p shaftless B (1)',
#  '7-pack STELLAN shaftless',
#  'Stellan 7-p shaftless BB',
#  'TP Stellan 7-p shaftless BB',
#  '7-pack WEEKDAY anklesock BB',
#  'TP Weekday 7-p anklesock BB',
#  'TP Lucas 7-p anklesock BB',
#  'TP ERIK REGULAR SOCK YB 10PACK',
#  'TP ERIK REGULAR SOCK BB 10PACK',
#  'Ellen Hipster Ch. Petunia 3p',
#  'Nohar.',
#  'Lola Denim Shorts',
#  'Daiquiri Pull- On TRS',
#  'Kurt sandal',
#  '5-pack BOB SPORT shaftless BB',
#  'Bob Sport 5-p midshaft BB',
#  'Bob Sport 5-p midshaft BB (1)',
#  'REBOUNDER tie tanga',
#  'REBOUNDER moulded triangle',
#  'Basic tights 2-pack',
#  'Basic tights 2-pack TVP',
#  'Leo seamless t-shirt',
#  'KENTY sweatpants SB',
#  'TP JACK fancy hood SB',
#  'JACK fancy hoodie SB',
#  'PAUL hood SB',
#  'ALBIN basic rib 2p SB',
#  'TP ALBIN basic rib 2p SB',
#  'TP ALBIN basic rib l/s 2p SB',
#  'Tika (1)',
#  'Nils woven pj BB',
#  'Rollerneck Blenheim',
#  'R-neck Astrix Lamswool',
#  'BD check Gerald C',
#  'BD check Gerald',
#  'TD Marx Flanel',
#  'Summer strap dress',
#  'STAR BRA',
#  'Sport sock 5-p anklesock BB',
#  'SPORTSOCK 5-p anklesock BB',
#  'Sport sock 5-p anklesock B (1)',
#  'Jake pile BB',
#  'JOANNA Tanktop',
#  'Dance shoe Sofia',
#  'Ilona Dance shoe',
#  'Cool Bree bandana',
#  'Thomas paperbag',
#  'Frame ls',
#  'Almodovar',
#  'Victory voile shirt',
#  'BORIS',
#  'BORIS SS SHIRT',
#  'Arthur slim fit shirt',
#  'Fredrik stretch shirt',
#  'FREDRIK stretch shirt',
#  'Fredrik Slim Stretch',
#  'SIRPA s.6',
#  'SORRENTO trousers (1)',
#  'SCULLY  jacket',
#  'PIMA shell trousers',
#  'MULDER trousers',
#  'ALASKA ski',
#  'TOBIE 3-pack l/s',
#  'TP TOBIE 3-pack l/s',
#  'TP TOBIE l/s SB 3PACK',
#  'Inca jumper',
#  'Maja  SS',
#  'Maja tee',
#  'Andre s/l pj BB',
#  'SB Tyler Sport Set LATE',
#  'BB Tyler Sport Set LATE',
#  'BB Tyler Sport Set',
#  'Sunday SL Set',
#  'Kimye hood',
#  'Wet Tee (1)',
#  'Wet Tee',
#  'PAULA tights',
#  'Iggy knit',
#  'Rebecca or Delphine shirt',
#  'Rebecca',
#  'Donna n-slip print (K)',
#  'Irma SL-set print (J)',
#  'BEN polo',
#  'BEN polo (1)',
#  'Tom shorts (1)',
#  'NIKE (1)',
#  'MOLLY',
#  'NT Senja dress',
#  'Juni 2pk Push Melbourne Micro',
#  'Kardashian skirt (1)',
#  'Vincent Dress',
#  'MAXI',
#  'Dolly leather sandal',
#  'LOTTIE TANK TOP',
#  'Cool Svea sunglasses',
#  'Sunglasses Neo Oval',
#  'Stuart Shirt',
#  'OL TRANCE',
#  'Nick super skinny',
#  'Hunter Super Skinny',
#  'Peter parka',
#  '3 PK R-NECK SS BASIC',
#  '3 PK V-NECK SS BASIC',
#  'Jonas 2-pack shorts BB',
#  'Jonas 2-p shorts BB',
#  'Gabby cross bag (1)',
#  'Gabby cross bag',
#  'Zlipperly swimsuit',
#  'Taurus tunic dress',
#  'Agnes LS R-neck',
#  'ESSENTIAL AGNES',
#  'NIKE 2p',
#  'Skinny HW shaping',
#  'James basic hip belt (1)',
#  'BB 2-pack Carter shorts',
#  'Carter shorts 2P',
#  'Sallly Structure',
#  'Sally Sweater',
#  'Sally Plain-Reverse',
#  'Beanie Levi Knitted',
#  'Flirty Anna headband',
#  'Dotty Hoodie',
#  'Angela m?gown',
#  'Mel maxi dress',
#  'HLW SB Full Suit Own',
#  'Full Suit Own',
#  'SB Cape Own',
#  'SB Cape Own fancy',
#  'X-mas Hat Own',
#  'STYLO SLIM SHIRT',
#  'Stylo smart shirt',
#  'Vermont',
#  'Sandra',
#  'RONJA',
#  'Ronja 5-pack brief solid',
#  'RONJA 5-p brief solid',
#  'RONJA 5-p solid briefs',
#  'Jack beanie',
#  '5-p Cecilia shaftless',
#  'Erik 10-p sock SB',
#  'ERIK REGULAR SOCK 10PACK',
#  'Vincent (1)',
#  'Alison dress',
#  'SPEED Salt',
#  'Salt',
#  'Basic Ls tee 1x1rib',
#  'Dora Dress (1)',
#  'MAX sweatpants 2-pack SB',
#  's',
#  'Olga',
#  'Olga Tank',
#  'Mike jogger',
#  'Boyfriend Short',
#  'LS body single mixed',
#  'Basic single jersey hood',
#  'Common',
#  'Tracy 2pk wirebra',
#  'Peggy PU',
#  'TILLY own graphic',
#  'TILLY 7-p OG briefs',
#  'Elliot 2-pack snug SB',
#  'TP Elliot 2-pack snug SB',
#  'Elliot 2-p l/l pj SB',
#  'Lassy Linnen LS',
#  'LS body fancy 2P',
#  '2P LS body fancy',
#  '2PACK LS body fancy TVP',
#  'LS body solid 5PACK',
#  '5PACK LS BODY SOLID',
#  'Basic Sweatshirt Overall',
#  'Holger Tights',
#  'Holger',
#  'Oliver Hood',
#  'NT Alva 2-pack',
#  'Boyfriend LW',
#  'Cotton eye shirt',
#  'Alex Trousers',
#  'Alex Trs (J)',
#  'Alex Trousers (K)',
#  'Dita dress',
#  'Bellini C/F',
#  'Bones utility trousers',
#  'Brandon (1)',
#  'BOSSE fancy OH hood SB',
#  'Clemenza Brazilian Acacia Mid',
#  'Neve Off-shoulder',
#  'MAGNUS sweatpant w panel SB',
#  'MISA silk/cotton hat (1)',
#  'Zelda Cardigan',
#  'Jade high',
#  'Beda TRS',
#  'OL BORG W.L sneaker',
#  'Kylie Shorts',
#  'Kylie Shorts (J)',
#  'JOEL basic 2-pack SB',
#  'SAGA OG Robe',
#  'Sport sock 5-p SB',
#  'Onesie Own Fancy',
#  'METS FANCY SHORTTOP',
#  'BO fancy OH BB',
#  'Salomon wool cap',
#  'SAlomon wool cap',
#  'Mama 20 den 2p Tights concious',
#  'BUCKLE UP top (1)',
#  'VICTOR 3PK SLIM VN T-SHIRT',
#  '3 PK V-NECK SS SLIM',
#  'KEVIN sweatpants non org BB',
#  'Danja Sweater',
#  'FEV Olle midlayer',
#  'Cool Claudio hoops',
#  'BERTIL 3-pack ss SB',
#  'TP BERTIL ss SB 3PACK',
#  'AXEL 2-pack s/s BB',
#  'TP AXEL 2-pack s/s BB',
#  'ALEX 2-p s/s SB',
#  'TP ALEX 2-p s/s SB',
#  'JOEL Sweatpants SB',
#  'JACK hood SB.',
#  'JACK hood SB',
#  'Rexona mini skirt',
#  'SKINNY 5 Pkt lined 79',
#  'Small Sarah cross bag',
#  'Bryan zip hoodie',
#  'Basic sweatpants 1',
#  'LACEY OG',
#  'Canterbury text sweater',
#  'Jordan (1)',
#  'SPEED Tessan',
#  'Elie shelltop woven',
#  'Denim jacket SPEED',
#  'Richmond plain',
#  'JALEN',
#  'Basic dungarees',
#  'JACK hood SB 2-p',
#  '2P LS PJ',
#  'Sergei boot PQ (1)',
#  'Chris Cargo',
#  'Spanx shape swimsuit BIG',
#  'Courtney jumper',
#  'HM+ Courtney jumper',
#  'R-Neck Jamber',
#  'Skinny Biker trash',
#  'KELLY S.7',
#  'KELLY S.9',
#  'DENISE .7',
#  'Kimbo Tee',
#  'Taylor Straw',
#  'rhea',
#  'TP BENNY basic crewneck BB',
#  'Julia Denim TRS',
#  'Julia RW Denim TRS',
#  'Julia Denim RW TRS',
#  'Victoria TRS',
#  'Victoria Pull- On TRS',
#  'SB Rico Trouser LATE',
#  'BB Rico Trouser LATE',
#  'SHORTS DUNGAREE BASIC 79',
#  'LEGGINGS AOP SPOT',
#  'SHORTS DUNGAREE BASIC 89',
#  'TW Dixie Windbreaker',
#  'Skinny L.W Elite',
#  'SKINNY Cheapo 79',
#  'Skinny Cheapo',
#  'DENIM JACKET BASIC',
#  'Petar Sweater(1)',
#  '2p Samantha Brazilian (Acacia)',
#  'Chili Brazilian (Acacia) 2pk',
#  '2p Majken Brazilian (Acacia)',
#  'Linn PJ',
#  'Frame Slim SS',
#  'FRAME short sleeve',
#  'FRAME SS',
#  'Liza 2p padded wireless rio mc',
#  'RC EVERT',
#  'Skinny Knit',
#  'JOGGER Knit 79',
#  'Carl low sneaker SB',
#  'JOGGER Knit 89',
#  'Jogger Knit 89',
#  'Fia 2-p knee high',
#  'Timeless Push Triangle',
#  'Timeless Top',
#  'Plain Jane Padded Swimsuit',
#  'Timeless Swimsuit',
#  'Frenchy Push (Balboa) 2pk',
#  'Frenchy Hip Ch (Poppy) L 3p',
#  'Scuba Gooding JR Brief',
#  'NORWAY fleece jacket (1)',
#  'Stina 5 pack boxer fancy',
#  'STINA 5PACK boxer',
#  'Billie.',
#  'Pernilla tunic',
#  'MALAGA (1)',
#  'Savoy cross bag',
#  "JONES TURD. DON'T PLACE",
#  'SB STRAW HAT',
#  'Ariel hip belt',
#  'Luna skinny 5 pkt',
#  'Stella cropped RW 5 pkt',
#  'Space jegging',
#  'Bloom straw hat SPEED',
#  'KRISTOFF fancy polo',
#  'Liseberg 5-p sock',
#  'MALCOLM sweatpant BB',
#  'MALCOLM sweatpants BB',
#  'TP MALCOLM sweatpant BB',
#  'Basic Hood AOP',
#  'GRETA HOTPANTS',
#  'Anthony 3pk Basic',
#  'Anthony Fancy',
#  'Chris 3pk R basic mid trunks',
#  'Chris 3pk fancy',
#  'Robin 3pk Basic',
#  'Robin fancy',
#  'PAUL  R-NECK',
#  'Cayenne highwaist',
#  '2p Hart Hipster modal (Poppy)',
#  'Timeless tie tanga',
#  'Tobie l/s SB',
#  'Chickory',
#  'Princeton shirt',
#  'Jamie stretch',
#  'FORTUNA',
#  'Malva 2pk Padded Bra',
#  'Brad Solid',
#  'Carla tee (1)',
#  'IZZY loose tee',
#  'BAMBAM loose top',
#  'TP Princeton shirt 1',
#  'SS Linen Mot',
#  'CA Hugh Linen shirt',
#  'Flora PJ NEW',
#  'BILLY basic 3-p s/s BB',
#  'BILLY s/s BB 3PACK',
#  'Hayes slim trouser',
#  'Mariette',
#  'Vermont Summer',
#  'Jingan',
#  'Anna lace 2-p',
#  'Vicky shoulder bag',
#  'Salina',
#  'VIKTOR basic ss SB 3-p',
#  'Polo L/S Metallica!',
#  'CHIPMUNK loose tee',
#  'Cecilia Kimono',
#  'DONT USE ROLAND HOOD',
#  'REX SLIM LS T-SHIRT',
#  'V-NECK SS BASIC FIT FANCY',
#  'ROY SLIM RN T-SHIRT',
#  'VICTOR SLIM VN T-SHIRT',
#  'ERIK REG TANK TOP',
#  'June leggings',
#  'Toscana/Vigo/Laquila',
#  'Lola 3p hipster micro v-s LR',
#  'Ariel boat neck',
#  'Stud tee dress (1)',
#  'Rosa padded bra BIG',
#  'NILS basic shorts SB',
#  'Taylor Fancy Denim',
#  'SB Gavin water resistan parka',
#  'OL 2-pack',
#  'TANKTOP LACE',
#  'TANKTOP LACE 17',
#  'ESSENTIAL TANKTOP LACE',
#  'FARIN RW cropped',
#  'HAVANA +',
#  '+ HAVANA HW tights',
#  'Beverly Denim TRS',
#  'Madison skinny HW (1)',
#  'IZZY+',
#  'IZZY+ (1)',
#  '+ IZZY loose tee',
#  'ANNA SS SLUB',
#  'Barza pant',
#  'TORBJORN 3-p LS BB',
#  'TOBIE 3-p LS BB ES',
#  'TP TOBIE 3-p LS BB ES',
#  'TP TOBIE LS BB ES 3-p',
#  'ORLANDO 2-layer tee (1)',
#  'ORLANDO 2-layer tee',
#  'Skinny HW trouser',
#  'Eva Hairy Off Shoulder',
#  'Panama fluffy cardigan',
#  'Karmi Cold-shoulder',
#  'Rachel L/S',
#  'Rachel Basic L/S',
#  'Rachel Basic LS',
#  'Edit viscose trs',
#  'Edit Trs (W)',
#  'FREJA 3-PACK',
#  'FREJA 3PACK',
#  '7pk Sneaker Sock',
#  '7pk sneaker sock basic',
#  'Jaquard shorts Grapefruit',
#  'Brian cargo (1)',
#  'Skinny Sunbeam Pink 79',
#  'SHORTS MANGO',
#  'NOORA 3-p hipster',
#  'Noora 3 pack',
#  'Stina 5-p',
#  'Petra 2-p',
#  'Stina fancy 3-p',
#  'Stina 3-pack fancy',
#  'Blondie Hairy Off Shoulder',
#  'Blonde cosy off- shoulder',
#  'Frenchy Thong (Maple)Low 3p',
#  'OL KATE PQ ballerina',
#  'Burmilla',
#  '3PK R-NECK LS SLIM',
#  '3PK R-NECK SS SLIM',
#  'ROY 3PK SLIM RN T-SHIRT',
#  '3PK ROY SLIM RN T-SHIRT',
#  'Riri sneaker',
#  'SWEATSHIRT AOP/RAGLAN',
#  'Fries & Ties shirt',
#  'TP Fries & Ties shirt',
#  'BENNO',
#  'Calista cardigan.',
#  'Calista',
#  'TURIN jersey pants TVP',
#  'Taylor Tshirt Milano',
#  'TURIN woven trousers',
#  'JAMES henley s/s SB',
#  'Billie bunny bag charm',
#  'Felix super stretch',
#  'Super Skinny Thrifty',
#  'Vintage H.W Ankle Petite',
#  'TOM FANCY UU',
#  'Anders Super Push',
#  'Anders Super Push (1)',
#  'SUNDAY hoodie',
#  'Bradley',
#  'Bieber strawhat',
#  'Shorts Slim Cash',
#  'OLIVER OXFORD',
#  'CARBON slacks cotto',
#  'LOGG Basic Hood',
#  'SPARKLES oversized tee',
#  'SPARKLES oversized tee (1)',
#  'Holly ballerina(1)',
#  'Amie ballerina',
#  'WALES REGULAR R-NECK',
#  'Merry Body.',
#  'MIMMI 3p',
#  '5P SS bodypack',
#  '5P SS BODY SOLID',
#  'Stud Tee (1)',
#  'Cap Paco Label',
#  'LOGG Fireball chino',
#  'Skinny H.W Air 19.99',
#  'Josef Clear glasses',
#  'Valentina Rem Pad Body LS',
#  'Niko 5-p boxer SB',
#  'Niko boxer SB 5-p',
#  'Niko 5-p boxer SB (1)',
#  'Niko 5-p boxer BB',
#  'Niko boxer BB 5-p',
#  'NIKO BOXER BB 5PACK',
#  'Niko 5-p boxer BB (1)',
#  'Finn 10-p shaftless SB',
#  'Finn 10-p shaftless BB',
#  'TP FINN SHAFTLESS YB 10PACK',
#  'Finn 10-p shaftless BB (1)',
#  'Shorts Skinny Barato',
#  'Shake it in Balconette_',
#  'Kurt col denim',
#  'Shorts Louie',
#  'Shorts Relaxed',
#  'TP TORKEL tanktop SB 3PACK',
#  'Jason basic SB',
#  'Paris highwaist',
#  'New girl push top',
#  'Flock',
#  'Hank Hawaii Shirt',
#  'Julius SB',
#  'PRINCE ERIC BASIC PROGRAM',
#  'Julius BB',
#  'SKINNY SATEEN 79',
#  'Cher sweater',
#  'OZZY LS BB NEW',
#  'Oprah 1p Tights',
#  '2P Jersey Tights',
#  'Jersey leggings 2PACK',
#  '2P Jersey Leggings',
#  'Cocos',
#  'Dress set',
#  'Kim Skinny Fit Blazer',
#  '2P SWEATPANTS',
#  '2PACK SWEATPANTS TVP',
#  'Ibiza HW Woven Relaxed  TRS',
#  'TOMMY sweatpants BB',
#  'TP TOMMY brushed sweatpants BB',
#  'TP THEO hoodie BB',
#  'THEO hoodie BB',
#  'Etno Denim Shorts',
#  'Mike s/s 2-pack pj BB',
#  'Mike 2-p s/l pj BB',
#  'MIKE S/L PJ BB 2PACK',
#  'VENICE hood deal',
#  'CECILIA 2p gown',
#  'Margarita RW Pull- On Shorts',
#  'Margarita Shorts',
#  'Kris Shorts',
#  'RELAXED TRASH MID 89',
#  'Falkenberg OTS (1)',
#  'R-NECK LS BASIC FIT',
#  'Lawrence',
#  'Holly 2p Unpad Sless Sleep Bra',
#  'Elliott 2-p snugfit BB',
#  'Pugsley padded jkt',
#  'Uno Padded jkt test',
#  'Torsten l/s BB',
#  'LUDDE l/s BB',
#  'Shorts Straight Long',
#  'SB BUCKET HAT',
#  'ELIN tee',
#  'Fiona 4pk Hipster OC MR',
#  'Timothy Hood PJ set',
#  'TAZ LONG RN T-SHIRT',
#  'Sky wide trousers',
#  'SHORTS PRICE',
#  'Kia Paperbag',
#  'Ivy shorts',
#  'Ivy shorts (1)',
#  'Hudson shorts',
#  'Simz anorak',
#  'Baby Love Top',
#  'CAGE SLIM EASY IRON US',
#  'Cage US',
#  'Cage easy iron',
#  'Ravel Runner',
#  'Timeless Higwaist',
#  'PAUL V-NECk',
#  'Volpino',
#  'Angela Cheeky Bk',
#  'Tequila shorts (1)',
#  'Adrien 2-pack pyj',
#  'Adrien 2-p pj BB',
#  'Adrien 2-p l/l pj BB',
#  'Flirty Amanda cat sunglasse',
#  'DUNGAREE SL',
#  'Basic Dungarees SL',
#  'Emma Brief',
#  'Fred Shortie 3 pack',
#  'Fred Basic',
#  'Skinny Ankle Color',
#  'Buckle up cheeky breif',
#  'Tie Basic Solid Wide Conscious',
#  'Hannes suede',
#  'Linnea PJ',
#  'Linnea PJ (K)',
#  'Soko Throw-on',
#  'Super Skinny Medieval',
#  'Arjen Cargo.',
#  'Arjen',
#  'Basic Girly romper',
#  'Call me top',
#  'Call me brief',
#  'Bud AOP',
#  'apri skirt',
#  'SKINFAXE SLIM MANDARIN SHIRT',
#  'Girlfriend R.W',
#  'The Firm',
#  'Noora 3 pack hipster fancy',
#  'NOORA 3PACK fancy hipster',
#  'NOORA 3-p hipster fancy',
#  'Queenie Jumpsuit',
#  'Scallop 5p Melange',
#  'ISAAC RXD RN T-SHIRT',
#  'AVOCADO HOOD',
#  'LARRY',
#  'SB Kevin Trousers LATE',
#  'BB Kevin Trousers LATE',
#  'BB Kevin Trousers',
#  'SB Jacob Hoodie LATE',
#  'BB Jacob Hoodie LATE',
#  'BB Jacob Hoodie',
#  'SB Bolt T-shirt LATE',
#  'BB Bolt T-shirt LATE',
#  'BB Bolt T-shirt',
#  'Vega sneaker',
#  'Polly blouse',
#  'Shorts SS Trash',
#  'Frida trouser (1)',
#  'dean dress',
#  'Scuba Gooding JR Triangel',
#  'OTTO sandal SB',
#  'EBBOT low SB',
#  'Tilly',
#  'Slim Straight 5pkt',
#  'Slim Straight 5pkt (1)',
#  'Bernie (1)',
#  'Charlotte Brazilian Low 2p',
#  'Bertil s/s SB',
#  'Nicke Basic s/s',
#  'Jefferson',
#  'Dyra 5-p shaftless',
#  'Dyra 5-p',
#  'Lazer Razer Adj. PTriangle',
#  'Pluto slacks',
#  'Firenze',
#  'ED Pamela (1)',
#  'SPEED Karma Dress',
#  'Luna destroy',
#  'Slim cargo',
#  'JANE trousers 2p',
#  '2nd skin',
#  'Juanos',
#  'Lotta Blouse',
#  'Firenze 3/4',
#  'Margarita tie bottom/lolita fu',
#  'Wally',
#  'Brad BF Denim TRS',
#  'Timeless Xtra cheeky brazilian',
#  'Gaetana 2p headband',
#  'Slim Straight 5pkt Midway',
#  'Ellen Wireless (Molly) 2pk',
#  'ED Friend cardigan',
#  'Bille straw hat',
#  'HM+ Glans tunic',
#  'wheeler jumpsuit',
#  'Lova Linen v neck',
#  'DIV Minna HW leggings',
#  'DIV Brenda trash dungaree',
#  'Malena',
#  'Mister Muscle SS',
#  'Mike 2-p s/l pj SB',
#  'Mike 2-p s/l pj SB (1)',
#  'Mike s/l pj SB (1) 2-p',
#  'Hera Jumper follow up',
#  'Mary jane Dress',
#  'Inca',
#  'Elson',
#  'TEA sport socks',
#  'FRITTE robe',
#  'Rally 2-p.',
#  'Rally 2-p tights SG',
#  'Marie 7-p. ankle sock',
#  'MY dress',
#  'NIKE legging',
#  'MALAGA legging',
#  'Big pilot sunglasses',
#  '2P LS body mixed',
#  'MISCHA tee',
#  'MISCHA tee (1)',
#  'FREJA',
#  'FREJA 2PACK',
#  'Flirty Karin headband',
#  'Shorts SS',
#  'ICE organic linen tee',
#  'Jade Denim Fancy Trash TRS',
#  'Jade Denim Trash TRS',
#  'Jade Denim HW Trash TRS',
#  'SB Petter parka price',
#  'Pete ss poplin',
#  'Josie Sandal',
#  'THEO 2-p hood BB',
#  'ALBIN 2-p l/S BB ES',
#  'SP balconette',
#  'Sonny loafer',
#  'Molly LS',
#  'JONATHAN LIGHT HOOD',
#  'REBECCA POINTELLE',
#  'Brenda elastic(1)',
#  'BRENDA LACE UP (1)',
#  'Chelsea WD trousers TP',
#  'TP Malcom 5-pkt',
#  'Jenny Boot',
#  'Shirt Dress Western',
#  'MAX fancy sweatpants 2-p',
#  'ANTHEA 2P PJ solid and pri',
#  'BB 2-pack T-shirts',
#  'Anthea single PJ',
#  'ANTHEA single PJ',
#  'Nike fancy legging',
#  'Nike fancy legging (1)',
#  'OPen old Raf',
#  '&DENIM Skinny shaping RW',
#  'ALGOT 2-p BODY BASIC',
#  'ALGOT LS Body 2PACK',
#  'ALGOT 2-p BODY',
#  'ALGOT body LS 2pack',
#  'Ronja fancy 5 pack brief',
#  'RONJA 5-p brief fancy',
#  'RONJA 5-p fancy briefs',
#  'TILLY 5PACK brief',
#  'SHORTS PRICE 89',
#  'ROY 5PK SLIM RN T-SHIRT',
#  'Faith OG pj',
#  'Josie pj SG',
#  'Masolo PJ single',
#  'SB Henry ski jkt TP',
#  'FILIPPA dungeree (1)',
#  'SB Ant waterproof pant(1)',
#  'SB Terry parka (CC)',
#  'SB Samuel puff jkt TP',
#  'Tina 7-pack brief',
#  'TINA 7-p fancy brief',
#  'HEIDI shorts',
#  'Henrik OH hood (1)',
#  'Feild OH hood CC',
#  'Honey leggings - TVP',
#  'HOLMES fancy',
#  'Holly Leggings',
#  'HOLLY (TVP)',
#  'Lena Pj',
#  'Helena Tank 2PACK',
#  'Blake slim fit linen blz',
#  'Clarence bottom',
#  'Clarence hipster',
#  'MC Dora dress',
#  'claudine',
#  'OL CARMELO PQ Wedge',
#  'Casablanca WD slim trousers',
#  'Casablanca WD trousers(1)',
#  'Jetplane',
#  'Skinny Altered (1)',
#  'REBECCA 2PACK tanktop',
#  ...]

# %% [markdown]
# #### Finding product codes associated with missing product names and adding those names to the dictionary

# %%
for i in missing_prod_name:
    x= df_articles.loc[df_articles.prod_name==i,'product_code']
    code=x.values[0]
    y=df_articles[df_articles.product_code==code][['product_code','prod_name']]
    product[code]=set(y.prod_name)
    missing_prod_name=[x for x in missing_prod_name if x not in product[code]]

# %%
missing_prod_name
# Out:
# []

# %% [markdown]
# #### The missing product names are now added to dictionary keys as set

# %%
product
# Out:
# {108775: {'Strap top', 'Strap top (1)'},
#  110065: 'OP T-shirt (Idro)',
#  111565: '20 den 1p Stockings',
#  111586: 'Shape Up 30 den 1p Tights',
#  111593: 'Support 40 den 1p Tights',
#  111609: '200 den 1p Tights',
#  112679: 'SWEATSHIRT  OC',
#  114428: 'Alice BANDEAU 2-p',
#  116379: 'Frugan longsleeve',
#  118458: 'Jerry jogger bottoms',
#  120129: 'Babette long',
#  123173: 'Control Top 50 den 1p Tights',
#  126589: '2p Claw',
#  129085: 'Pirate Leggings (1)',
#  130035: 'Black Umbrella',
#  141661: 'Velour pyjama',
#  144993: 'Mama 100 den 1p Tights',
#  145872: 'Dorian l/s basic',
#  146706: {'3P TANKTOP BODY', 'Tanktop body white 3PACK'},
#  146721: 'Hair Ring',
#  146730: '200 den 1p leggings',
#  147339: '6P SS BODY',
#  148033: 'Nouvelle 1p Stay Up',
#  150959: 'THOMPSON woven sport pants',
#  153115: 'OP Strapless^',
#  156224: 'Box 4p Socks',
#  156227: 'Box 4p Kneehighs',
#  156231: 'Box 4p Tights',
#  156289: 'Slim Cheapo 79',
#  156610: {'Anton sport pant', 'Connor pants'},
#  158340: 'Highwaist 30 den 1p Tights',
#  160442: {'3p Sneaker Socks', 'Sneaker 3p Socks'},
#  162074: 'Sigge sneaker sock 5p',
#  163734: 'KOMPIS 2-pack L/S',
#  164912: 'Scallop 5p Socks',
#  174057: 'FLEECE PYJAMA',
#  176209: 'Mr Harrington w/hood',
#  176550: 'Sleep bag padded',
#  176754: '2 Row Braided Headband (1)',
#  179123: {'Long Leggings', 'Long Leggings (1)'},
#  179208: 'Control Top 100 den 1p Tights',
#  179393: 'Basic 2p Overknee',
#  179950: 'Austin basic leather hip belt',
#  181160: 'Eva chelsea boot',
#  181448: 'Jenny 5-pack',
#  182909: 'Fleece 1 p tights',
#  183815: 'Bobby elastic waist belt',
#  184121: 'FIFTY SHADES moulded halternec',
#  184123: 'FIFTY SHADES  tie brief',
#  184583: 'Robin 3pk solid',
#  186262: '4p Claw',
#  186264: '10p Terry w.o. Clip',
#  186266: '10p Basic Terry',
#  186267: '12p Claw',
#  186372: 'Harem trousers',
#  186595: 'Lena over knee.',
#  187949: 'Padded pyjama',
#  188183: {'SPANX ALOT swimsuit (1)',
#   'Spanx alot Swimsuit',
#   'Spanx alot shape Swimsuit'},
#  189383: 'BASIC LS TURTLE NECK BODY',
#  189616: {'Heavy jsy long leg', 'Tina leggings'},
#  189626: 'Jodi skirt',
#  189634: 'Long Leg Leggings',
#  189654: 'Raven skirt',
#  189691: 'Carolina sweater (1)',
#  189955: 'Nora tee',
#  190021: 'Basic 5p Minishaftless',
#  190252: 'Chris 3pk solid',
#  192460: 'Knit dress',
#  192960: 'Neo running beanie',
#  194037: 'Fleece leggings 1 p',
#  194242: 'HONEY L/L Leggings',
#  194270: 'HELENA 2-pack tanktop',
#  194902: 'BERTIL Basic 2-pack S/S SB',
#  198518: {'METS 2-p basic shorttop', 'METS 2-p shorttop'},
#  198714: 'Babette cropped',
#  199119: 'Basic shorts',
#  200182: '40 den 2p Tights',
#  200761: {'TORKEL Basic 2-pack tanktop SB', 'TORKEL tanktop SB 2-p'},
#  201219: 'Heavy plain 2 p tights',
#  202017: 'Rihanna dress',
#  203027: 'Linni tee (1)',
#  203595: 'Bryn Flanel Check',
#  204892: 'Frode outdoor beanie',
#  205225: 'PICKUP ARTIST top',
#  211143: {'Janet SL (W)', 'Janet SL-set (W)'},
#  212042: 'Mimmi sneaker',
#  212629: 'Alcazar strap dress',
#  212766: 'Dean Drawstring Trousers.',
#  213690: 'H-terry Basic 16-pack',
#  213691: 'H-string Jersey',
#  214844: '30p pins',
#  215248: 'Bob v-neck tee',
#  215303: 'Coolio sunglasses',
#  215324: 'Classic Fancy pilot (1)',
#  215337: 'Pamela tee',
#  215589: 'Mama 40 den 2p Tights',
#  216081: 'Norling Knit',
#  216961: '4p Elastic Headband (1)',
#  217207: '2P SS PYJAMA',
#  217727: 'Polly 3p minishaftless',
#  218354: 'Beyonce cropped tank',
#  218829: 'Paris glove.',
#  219075: 'Billy cargo pants',
#  220094: 'Aguilera maxidress',
#  220365: {'Cool Olja round', 'Olja sunglasses'},
#  224314: 'Pinocchio hat',
#  224337: 'New Carrie Glove',
#  224521: 'DERRIDA windstopper tights',
#  224606: {'Flora hip belt', 'Flora hip belt (1)'},
#  225286: 'Gauss windproof zip top',
#  225784: 'HARLEY 2-pack basic tee',
#  226011: 'Flirty Maria 2p Hawaii',
#  226959: 'Astaire 1p Overknee',
#  228257: '20 den 2p Tights',
#  233091: 'Magic Gloves 2pack',
#  233672: 'V-NECK LS SLIM',
#  234187: {'Cap Paco Solid CO', 'Paco solid flatpeak'},
#  234421: 'Mama 200 den Tights',
#  234432: 'Push Up 30 den 1p Tights',
#  234622: {'RAF basic 2-pack rollerneck SB', 'RAF basic rollerneck SB 2-p'},
#  235596: 'Basic 4pk studs',
#  235732: 'Emma long-john PJ (K)',
#  237032: 'Fancy long Leg Leggings',
#  237222: {'Helsinki', 'Ingrid'},
#  237347: {'Theron', 'Theron (1)'},
#  238197: 'Lima l/s',
#  240561: 'Support 70 den 1p Tights',
#  240670: 'Tess tee (1)',
#  240840: 'BASIC JERSEY TIGHTS OC',
#  241412: 'AOP Leggings',
#  241436: 'Fix it tote bag',
#  241486: 'MILL blocking tights',
#  241590: 'Matt black SF regular fit blz',
#  241602: 'Manson SF slim fit blazer',
#  242354: 'CALVIN running shorts',
#  243613: 'Minna highwaist leggings (1)',
#  243937: 'Straight Edge 5p Socks',
#  244267: 'Silver lake',
#  244269: 'Basic Henley body',
#  244853: 'Basic Hood',
#  245348: 'Santa Hat',
#  247072: '2P SS Girly PJ',
#  249136: 'Skinny Ankel Denim',
#  250099: 'Mama Heavy Plain 2p Tights',
#  250457: 'Brandon denim cropped',
#  251510: 'Push up 70 den 1p Tights',
#  252229: 'Lory sweatpants (1)',
#  252298: {'Danae jeans', 'Didi denim'},
#  253176: 'PICKUP ARTIST cheeky brief',
#  253448: 'OP Push Melbourne^',
#  254303: 'Bernard half calf socks',
#  254457: 'Basic SS dress',
#  254940: 'Elsa high waist',
#  255396: 'Nora Cardigan',
#  256096: 'Basic SS henley t-shirt',
#  256151: 'Superstretch Fancy denim',
#  256511: 'WIDEAWAKE triangle',
#  256513: 'WIDEAWAKE tie tanga',
#  257430: 'ROMY 2p',
#  257667: 'Lizzie',
#  258650: 'Berlin boot',
#  260736: 'NATE  basic S/S solid tee BB',
#  261526: 'ELLA 5-p shaftless',
#  261606: 'THALES tanktop',
#  261840: 'ELLA 5-p shaftless',
#  262277: 'Kim superskinny low waist',
#  264713: 'Al Car Shoe',
#  264984: 'Billie',
#  265069: 'PELLE Basic S/S jersey polo SB',
#  265071: 'KRISTOFF Basic jersey polo BB',
#  265630: 'Invisible 3p minishaftless',
#  266168: 'Shaper Shorts (1)',
#  266873: 'Micro 2p minishaftless',
#  266875: 'Sportsneaker 3p socks',
#  268305: {'Flirty Kattis Cat (1)', 'Kattis cat sunglasses'},
#  268450: 'LIAM 2-pack tanktop SB',
#  269342: 'Tina NT s/s',
#  270375: 'Sandra squared',
#  270381: {'Classic Clubba', 'Clubba sunglasses'},
#  270382: 'Burnie sunglasses',
#  272591: 'Lena Rib Dress (1)',
#  275362: 'Jersey harem shorts',
#  276242: {'Dress LS Basic', 'LS frill dress'},
#  276540: 'PEP PJ 9.99',
#  277738: 'Basic overall',
#  278038: 'LORA',
#  278563: 'Harris cross sandal PQ',
#  278811: {'Hilly Biker 2pk HW LS', 'Hilly Biker 2pk LT'},
#  280256: 'Mirage Push',
#  282832: {'Kevin softshell jacket', 'Kevin softshell jacket (1)'},
#  283236: 'Howie SS Shirt',
#  283532: 'Hanny Padded bra E&F',
#  283937: 'MASOLO PJ LONG LEG 14.99',
#  284985: 'BUDDY 2-pack L/S',
#  285143: 'HOLMES Sweat Trousers',
#  285602: 'SS body with collar',
#  286536: 'Layla Push',
#  287645: {'2-p micro tights SG', 'Microtights 2pk SG'},
#  288575: 'Basic s/s henley body',
#  288825: {'2-p Babsan tights BG', 'Babsan 2-p tights', 'Babsan 2-p tights BG'},
#  288859: {'Kakan 2-p cableknit BG', 'Kakan 2PACK tights BG'},
#  289597: 'UMBRELLA',
#  289834: 'FANTASTIC SHOPPER',
#  290022: 'Boris cap',
#  290519: {'Basic co/fl cardigan', 'Co/fl cardigan'},
#  290675: 'Coyote padded vest',
#  291333: {'2-p Keri',
#   '2-p Keri tights SG',
#   'Keri 2PACK tights SG',
#   'Keri 2pk tights SG'},
#  291338: {'2-p Pelin pointelle',
#   '2-p Pelin pointelle SG',
#   'Pelin 2PACK tights',
#   'Pelin 2pk pointelle tights'},
#  291957: 'Chelsea welldressed trouser',
#  292453: 'Flirty Chantal earring',
#  292551: 'SOFIE BEANIE',
#  293244: {'2-p micro tights BG', '2-p microtights BG', 'Micro 2pk tights BG'},
#  293433: {'2-p basic cotton tights SG',
#   'Basic 2PACK tights KG',
#   'Basic 2PACK tights SG',
#   'Basic 2pk tights SG'},
#  293510: {'2-p basic cotton tghts',
#   '2-p basic cotton tights BG',
#   '2-p basic tights BG',
#   'Basic 2PACK tights BG',
#   'Basic 2PACK tights YG'},
#  294008: {'Cora T-shirt', 'HM+ Cora tee'},
#  294076: 'Skinny Shaping',
#  294237: 'Aurora winter cap',
#  294895: 'Rodney basic beanie',
#  295873: {'Glove Sune Leather', 'Sune leather glove'},
#  296366: 'Flirty Fiffi flower headband',
#  296375: 'Flirty Fiffi 2p flower',
#  296471: 'TINA 7-P',
#  296476: 'DIVA ROBE',
#  297067: 'Small dot 1p Tights',
#  297078: 'Heavy Chain 1p Tights',
#  297791: 'Thigh High 1p Overknee',
#  297796: 'Spearmint shorts',
#  297898: 'Skinny high waist black',
#  299668: 'Sanne treggings (1)',
#  299733: 'Hilton',
#  299768: 'Peder knitted glove',
#  299841: 'Haakan',
#  300024: {'Super skinny denim', 'Superskinny'},
#  300637: 'Fingerless knitted 2-pk',
#  300696: 'Glove Magic Touch Pack',
#  300907: 'Sean Biker',
#  300908: 'Freja Coat',
#  301213: 'Tilda clean padded bra (1)',
#  301227: {'10pk basic R socks', '10pk regular'},
#  301364: 'Ozzy',
#  301517: 'Cool Kajsa Headband',
#  301656: {'Lou Shirt Dress', 'Shirtdress Lou'},
#  301668: 'Elly tights',
#  301687: {'Lurex tights BG', 'Lurex tights Bg'},
#  301901: 'Jenny Cardigan',
#  302311: 'Wales sweater',
#  302334: 'Sebastian braided belt',
#  304576: 'FORTUNA T-SHIRT',
#  304692: 'Mohair 2p Kneehigh',
#  304766: 'Mohair 2p Heavy Socks',
#  304778: 'Cosy 1p Lounge sock',
#  304786: 'Traditional 2p Heavy Socks',
#  304946: 'Leon',
#  305304: 'Boy Denim Shorts',
#  305305: 'Shaping Skinny R.W Ankle',
#  305584: 'Rose lace (1)',
#  305775: 'Lurex tights SG',
#  305931: 'Fake 1p Leggings',
#  306307: 'Lima ss',
#  306847: {'HONEY 2-P LEGGINGS',
#   'HONEY 2-P LEGGINGS (T VP)',
#   'Honey Leggings 2PACK (TVP)',
#   'Honey Leggings 2PACK - TVP'},
#  307239: {'Hilly Brief 2pk HW LS', 'Hilly Brief 2pk LT'},
#  307656: 'Maria Shorts',
#  307847: 'Vibeke 2-p',
#  307952: 'Hype',
#  308154: 'LS Body with collar',
#  308158: 'LS body girly with collar',
#  309434: {'COSY COTTON FLEECE ROBE', 'COSY ROBE'},
#  309509: 'Peggy Padded jacket',
#  309864: {'Skinny Cheapo 89', 'Skinny Cheapo 89 (1)'},
#  310091: {'3P LS PJ feet',
#   '3P LS PJ feet w zip',
#   '3P LS PJ with feet',
#   '3PACK LS PJ feet w zip'},
#  310365: 'RENEE REVERSABLE SCARF',
#  311059: 'BEN fancy crewneck SB',
#  312058: 'SS body girly with collar',
#  312543: 'Biker Leggings (1)',
#  312829: 'Cobra Tube.',
#  312878: 'Pablo coat',
#  315352: 'Edit dress (1)',
#  315497: 'Otto Beanie',
#  315509: 'Wolf Scarf',
#  315795: 'Braces Tweed 3-Clip',
#  315987: 'Pierre Beanie',
#  316008: 'Salinas Scarf',
#  316085: 'Peggy polo',
#  316242: 'Victoria (1)',
#  316441: {'Lee', 'Lee (1)'},
#  316471: 'Klein',
#  316553: 'Washington dress',
#  316657: 'Karenina Jacket',
#  317055: 'Racer Tank Fancy License',
#  317348: 'Elvis jumper',
#  317812: 'LOLLY SKIRT (1)',
#  318035: 'Classic Clear umbrella',
#  318066: 'KIMBERLY Braided Headband',
#  318238: 'Braces Frank 3-Clip',
#  318914: 'Basic cotton fleece leggings',
#  318951: 'Basic LS t-shirt',
#  319811: 'Basic tanktop romper',
#  319906: 'Steve Slipper',
#  320524: 'Sergio Knitted Scarf',
#  320880: 'JOAN SUEDE BOOT',
#  321249: 'Xmas Bauble 1p Socks',
#  321591: 'Stefan Scarf',
#  322017: 'Mini Umbrella',
#  322322: {'Beanie Pelle wool mix', 'Pelle Beanie'},
#  323274: 'SIGGE LICENSE (1)',
#  324375: 'MARY KATE EARMUFFS',
#  324502: 'Hawlin Headband',
#  324946: 'Control Top 200 den 1p Tights',
#  324963: 'Classic PU sunglasscase',
#  325027: 'Irina Softbra 2pk',
#  325087: 'Kelly (Melbourne) PUSH 2p',
#  325542: 'Nina Nightshirt (W)',
#  326885: {'MAX jersey pants SB', 'TP MAX jersey pants SB'},
#  327144: 'Rally 2p tights',
#  327310: 'Alicia wrap skirt',
#  327368: 'HOLLY L/L leggings',
#  327821: 'MALAGA 2-P',
#  328480: 'Tech basic pants',
#  329052: 'ANDERS SP',
#  331062: 'Christmas pyjama (1)',
#  331072: {'Kobe Low Chelsea Boot', 'Kobe boot'},
#  331093: 'LEA jumpsuit',
#  331474: {'JOEL Fancy sweatpants SB',
#   'JOEL fancy sweatpant SB',
#   'TP JOEL fancy sweatpant SB'},
#  332055: 'Flirty Emma takeyaway mug',
#  333159: 'Glacier self warming tights',
#  333323: {'Basic rolltops', 'Basic rolltops 3-pack', 'Basic rolltops 3PACK'},
#  333353: {'Classic Fido dog sweater', 'XMAS Fido dog sweater'},
#  334077: 'Emmons self warming top',
#  335037: 'HM+ Hilly Biker 2pk',
#  335896: 'Salamander L/S',
#  335991: 'XMAS Deer aliceband',
#  336125: 'SOLID PONCHO',
#  336881: 'Cypress leather pants',
#  337777: {'Easy iron L/S shirt',
#   'Easy iron L/S shirt  TP',
#   'Easy iron L/S shirt TP',
#   'Easy iron l/s shirt',
#   'TP Easy iron L/S shirt'},
#  337991: {'NEW Sigge dressed belt', 'Sigge Dressed Belt'},
#  338016: {'Basic Rollerbuckle belt', 'NEW Basic Rollerbuckle'},
#  338400: 'Hilly Thong 2pk',
#  339252: 'Hat Fredrik Paper Straw',
#  340223: 'Flirty Jingle headband',
#  340546: 'PAUL R-NECK',
#  341129: 'Mama Support 70 den 1p Tights',
#  341186: 'Bare legs Support',
#  341242: 'Dave waistcoat',
#  341452: 'Venice molly padded softbra',
#  341782: 'RILEY T-SHIRT',
#  341909: 'REBECCA basic tanktop',
#  341917: 'Holly halloween hair clips',
#  342034: 'Indiana Solid Scarf',
#  342060: 'Heavy plain Overknee 1p Tights',
#  342345: '3P LS PJ',
#  342434: 'Beanie Jimmy Jersey',
#  342840: 'Flirty Christmas Calendar',
#  342954: 'ZORROW DETAILED',
#  343973: 'Sara 2-p legging w lace',
#  344534: 'Gwen',
#  344625: 'ELLEN Sunhat',
#  344627: 'BASIC Sunhat',
#  344905: 'Seamless Push-up Biker',
#  344956: 'Flirty Romi waterbottle',
#  345815: '2PACK Tanktop Body TVP',
#  345830: {'2P Tanktop body girly',
#   '2PACK Tanktop body girly',
#   'Tanktop body Girly 2-pack'},
#  345922: 'Erling Necktube',
#  346539: 'Pattern 5p Socks',
#  347182: 'Josh Webbing Belt',
#  347200: 'Bo Dressed Belt',
#  347975: '2PACK SS Body TVP',
#  347983: 'SS Body Mixed 2P',
#  348168: 'SKINNY Price 89 (1)',
#  348330: {'2P Tanktop body Mixed',
#   '2PACK Tanktop body Mixed',
#   'Tanktop body Mixed 2p'},
#  348442: 'Gilberto top',
#  348657: 'Sofia Simple Choker',
#  348870: 'Mary Kate L/S',
#  348995: '3p fancy tanktop body',
#  349080: 'Block 1p Overknee',
#  349301: 'GLASSIG ESPADRILLE',
#  349669: 'Lenny braces',
#  350082: 'Hayes',
#  350135: 'Basic jersey pant 1x1rib',
#  350911: 'Bowtie Kalle',
#  351098: 'Wool Scarf Akira',
#  351182: 'Glove Suede',
#  351332: 'Marshall Lace up Top',
#  351462: 'LAZER RAZER bandeau',
#  351484: {'LAZER RAZER brief', 'LAZER RAZER brief (1)', 'Lazer Razer Brief'},
#  351771: 'Angela cheeky back',
#  351914: 'Fred Basic (1)',
#  351933: 'Kelly Lace Padded Idro 2p',
#  352811: 'Sara long (1)',
#  354041: 'Flirty New years Aliceband',
#  354246: 'Basic LS Raglan t-shirt',
#  354307: 'Akoni Flatshoe',
#  355062: 'HW Garbo mask',
#  355072: 'Anita Tank (1)',
#  355307: 'Moa tanktop',
#  355325: 'LUKE 2-pack L/S Rib BB',
#  355421: 'Colette dress',
#  355569: 'Nicky Long',
#  356004: 'ZORROW CLEAN',
#  356174: 'Space Treggings s5',
#  356289: {'JESSY SKIRT', 'Jessy skirt'},
#  356438: 'Flirty Millie shell',
#  356693: 'Gigi fake suede p cap',
#  357130: 'MIMMI',
#  357751: 'Basic Endless hoop',
#  357792: {'Alessa cat sunglasses', 'Cool Alessa Cat'},
#  358254: 'Mandy shorts',
#  358383: 'Cap Eazy Suede Peak App',
#  358483: 'Stressan light knit jumper',
#  358753: 'Basic Ronaldo necklace',
#  359043: 'Basic cotton terry shorts',
#  359504: 'Viola trs (W)',
#  359804: 'SOFIE THIN BEANIE',
#  359909: 'Solid Paco',
#  360295: 'Kardashian shopper',
#  360859: 'Chelsea welldressed blazer',
#  360950: 'Sunglasses Edward',
#  361401: 'Chloe 3/4 AOP',
#  361467: 'Claire S/S',
#  361531: {'Raymond aviator', 'Sunglasses Raymond Aviator'},
#  362219: 'Mama Support 30 den 1p Tights',
#  362931: 'WAFFLE L/S CTN basic',
#  362997: 'Miami tanktop',
#  364297: 'SWEATPANTS OC',
#  364409: {'SYBIL sleeping mask', 'Sybil sleeping mask'},
#  365025: 'Petra fancy shorttop 2p',
#  365058: 'Shorts-Sliq-Cut-Off-Bright-Na',
#  365102: 'Urban USB cable',
#  365439: 'Lawrence training sock',
#  365592: 'MIKKI SLIP ON SNEAKER',
#  366686: {'Tail tee', 'Tail tee (1)'},
#  366859: {'Reggie chino shorts', 'Reggie solid chino shorts'},
#  367194: 'Mott glove',
#  367372: 'Mama 200 den Leggings',
#  367376: 'Black umbrella',
#  368038: 'Biq Square Claw',
#  368300: {'ROCK SHORTS', 'Rock Relaxed Shorts'},
#  368505: 'Timon coat',
#  368603: {'ANTHEA pj', 'ANTHEA pj (1)'},
#  368979: 'ED Long leggings',
#  369423: 'Heart sunnies',
#  369796: {'Cool Metal John Round', 'John sunglasses'},
#  370594: 'Saya sunglasses',
#  370737: 'Sunglasses Blixa CO',
#  370868: 'Virginie shorts 2p (K)',
#  372008: 'Halter',
#  372576: 'Robin 7pk Basic',
#  372628: 'Spencer Softbra 2pk',
#  372860: {'7p Basic Shaftless', 'Basic 7p Shaftless'},
#  373493: 'Everyday 5p shaftless',
#  373506: 'Trainer 3p sock',
#  373698: '3P tank PJ',
#  374762: 'Wilma dress (1)',
#  375248: {'LOVE 2-pack lace leggings',
#   'LOVE 2-pack leggings',
#   'Love leggings 2PACK',
#   'Love leggings 2PACK-superspeed'},
#  375585: 'Sigge shorts',
#  375849: 'Penny 70s baseball',
#  375917: 'Hat Frank Fedora(1)',
#  376172: 'Karla sunglasses',
#  377239: 'Basic Loose Jerseypants',
#  377266: 'Sadie strap',
#  377277: 'Svea Cropped Tank',
#  377289: 'EASY PEASY swimsuit (1)',
#  377436: 'Flirty Real flower shell',
#  378124: {'L/S Polo Gnocci', 'L/S Polo Gnocci TVP'},
#  378135: {'R-Neck Merino Pisa', 'R-Neck Pisa', 'R-Neck Pisa TVP R'},
#  378447: {'V-Neck Merino Milan', 'V-Neck Milan', 'V-Neck Milan TVP'},
#  378719: 'Flirty Milkyway Eardeco (1)',
#  379360: {'MAXI 2 pack', 'MAXI 2PACK'},
#  379780: 'Rita Ringer Tee',
#  379963: 'Mama plain cotton leggings 2p',
#  380193: 'Cameron Cut Off',
#  380609: 'Livia Top',
#  380894: 'Chlo̩ cosmetic bag',
#  381038: 'Cori cropped hood',
#  381187: 'Lottie Tee',
#  382127: 'Roman running hood',
#  382468: 'Backpack Oliver',
#  383152: 'Henric Superpush',
#  383569: 'SPEED Pavlova dress',
#  384263: 'Sonny Denim',
#  384482: {'Godfather SF Chino', 'Godfather slim chino'},
#  384654: {'Wanda Dress', 'Wanda Dress (1)'},
#  384851: 'Sage Shorts',
#  386399: '3P SS PJ',
#  386463: 'Cool Betty earring pk',
#  386678: 'Big Arjuna crossbag',
#  386681: {'Mini Cross Bag', 'Mini cross bag'},
#  386695: 'Penny leather cross',
#  386859: {'Allington R-neck',
#   'R-neck Allington',
#   'T-Shirt Allington R-neck',
#   'T-Shirt Allington R-neck!'},
#  387348: 'Thales printed tanktop',
#  387426: 'Goodman light shorts',
#  387444: 'Petit cross bag (1)',
#  387843: 'Richie Regular Hood',
#  388573: 'Wera western belt',
#  388916: 'Washed Leather belt',
#  389236: 'Nate Anorak',
#  389388: 'Stef training gloves',
#  389479: 'Iwa Nightslip (J)',
#  389892: 'Poppy Poncho (1)',
#  390469: 'Meadow Push Bonny',
#  390512: 'Haddock Beanie',
#  390531: 'Sian Headband',
#  391032: {'Cap Eazy Badge', 'Eazy Badge Cap'},
#  391598: 'AZELIA IPHONE CASE',
#  391750: 'Manson trs',
#  391772: 'Matt regular trs',
#  392126: 'Claesson Leather Weekend',
#  392168: 'Lilly Twill Shorts',
#  392203: 'Vera backpack',
#  392220: 'Tie Mini Dot',
#  392269: 'CORBY TANK',
#  392820: 'Ralf Anchor Wrap Around',
#  392933: 'Ida Padded bra (1)',
#  392938: {'TD Hugo Stretch',
#   'TD Hugo Stretch PQ',
#   'TD Hugo slim fit Stretch PQ'},
#  393321: 'Skeleton 1p tights',
#  393447: 'Leia Parka',
#  393750: 'Agnes polo',
#  393772: 'Sonny Pants.',
#  393993: 'Fuji jacket',
#  394292: 'Sunglasses Morris',
#  394522: 'TD Ulrik',
#  394798: 'S/S Hugo Stretch C/R',
#  394803: 'Asteria Tank',
#  395127: {'CA Gustavsberg',
#   'CA Gustavsberg TVP',
#   'CA Gustavsberg slim fit TVP'},
#  395575: 'Emily Brief',
#  395619: 'Malcolm Skinny 5 pocket',
#  395658: 'MIA (1)',
#  395730: {'MUMS',
#   'MUMS (1)',
#   'VIOLA 2-pack',
#   'VIOLA 2-pack (TVP)',
#   'VIOLA 2PACK'},
#  395864: {'RAKEL 3p', 'RAKEL 3p boxer'},
#  396135: 'Glamping',
#  396690: {'Bracelet Lincoln CO', 'Lincoln Itlay String Bracelet'},
#  397068: 'Skinny L.W Bargain (1)',
#  397376: 'Elmer Elastic Belt',
#  397688: 'R.W Shorts Cut Off',
#  397807: 'Smoky padded ski pant',
#  398074: 'Sara 3/4',
#  398089: 'Shorts R.W Bargain',
#  398127: 'Shorts R.W Kelly',
#  398559: 'Molly T-shirt',
#  398814: 'Thomas tanktop',
#  398829: 'Shelly Wide Shorts',
#  398863: 'Wave shorts',
#  398947: 'Astrid round sunglasses',
#  398959: 'Stella sunglasses',
#  399036: 'Vera sweater',
#  399061: {'Jacket Slim', 'Jacket Slim (1)'},
#  399087: {'S.Skinny L.W Epic', 'Super Skinny L.W Epic'},
#  399136: {'Shaping Skinny R.W', 'Shaping Skinny R.W.', 'Skinny Shaping R.W'},
#  399201: {'Shaping Skinny H.W', 'Skinny Shaping H.W'},
#  399223: {'Curvy Jeggings HW Ankle', 'Jeggings H.W'},
#  399256: 'Skinny Ankle R.W Brooklyn',
#  399589: 'Pocketknit',
#  400246: {'Feather Jegging L.W.', 'Feather Jeggings L.W'},
#  400285: 'Straight R.W',
#  400296: 'Culotte',
#  400319: 'Boyfriend L.W.',
#  400342: 'Slim 5pkt Midprice',
#  400456: 'LS Body Solid 2PACK',
#  400489: 'Straight 5pkt',
#  400901: 'KNEE HIGH SOCK',
#  401020: 'Zip knit (1)',
#  401044: 'Cora Dress',
#  401136: 'Carla parka (1)',
#  401729: {'CHRISTINA BOOT', 'CHRISTINA BOOT (1)'},
#  401902: 'Go light jacket',
#  402065: {'OSCAR l/s tee SB', 'TP OSCAR l/s tee SB'},
#  402361: 'Smith light weight racerback',
#  402382: 'Icona Premium scarf',
#  402389: 'Icona premium beanie',
#  402595: 'Oskar glove',
#  403392: 'TOMMY basic sweatpants BB',
#  403421: 'THEO basic hood BB',
#  403448: {'GREG 2-p tanktop BB', 'GREG tanktop BB 2-p'},
#  403479: {'BILLY Basic 2-p S/S r n BB',
#   'BILLY s/s BB 2PACK',
#   'TP BILLY Basic 2-p S/S r n BB'},
#  403490: {'ELIAS basic 2-p V-neck BB', 'ELIAS basic V-neck BB 2-p'},
#  403579: 'JONES l/s Henley BB',
#  403844: 'Montana pants',
#  403994: {'Vegas (W)', 'Vegas Shorts'},
#  404383: 'Butch hood',
#  404441: 'Lesly neck gaitor',
#  404609: 'Jerry singoalla top',
#  404864: 'Basic Cool Pants',
#  405310: 'Ciara sunglasses',
#  405586: 'Volly jumper (1)',
#  405635: 'Polly Jacket',
#  405636: {'JIMMY raglan l/s BB', 'JIMMY raglan tshirt BB'},
#  405676: 'Romeo push Melbourne',
#  405887: 'NORA',
#  406155: 'Pack Santa',
#  406160: 'Atlas',
#  406181: 'Newman dress',
#  406724: 'Sunglasses Hendrix',
#  406979: 'Corinne jumpsuit',
#  406987: 'Tony woven jumpsuit',
#  407031: 'Midge top',
#  407040: 'Daphne l/s',
#  407147: 'Adele LS',
#  407354: 'Jack jersey denim',
#  407653: 'Basic 9-pk studs',
#  407663: 'Class Jacob studpk',
#  407806: 'Class Ture bangle',
#  408045: 'Sickan Shopper',
#  408104: {'TD Roger', 'TD Roger eller TD Poplin 29 by'},
#  408554: 'Rolled edge 3p Socks',
#  408569: 'Lurex 2p Sock',
#  408571: 'Tua 2p kneehigh',
#  408575: 'Papai 1p Overknee',
#  408647: 'Chenille 2p Lounge sock',
#  408649: 'Fun Chenille 2p Lounge sock',
#  408664: 'X-mas 2p Heavy Socks',
#  408875: 'Goldie tank top',
#  408884: {'Bangle Bracelet', 'Bracelet Bangle CO'},
#  409683: 'Verona Tank',
#  409730: 'Granada tank',
#  409731: 'Cornell ss jumper',
#  410024: 'Mr Bomberton',
#  410291: 'HoneyMelon',
#  410424: 'STINA fancy',
#  410549: 'Riga PJ',
#  410624: 'Mitch top',
#  411013: 'Rut Jumper',
#  411413: 'Brooke raw cut ss',
#  411499: {'Emil (1)', 'Emil Derby Shoe'},
#  411565: 'Clear glasses Hendrix',
#  411569: 'Tie Basic Solid Conscious',
#  411758: 'Jonas slim 5 pkt',
#  411974: 'OL BLIXTEN PQ sneaker',
#  412031: 'Skinny denim 5 pkt panel',
#  412043: 'Basic didier 6-p',
#  412333: 'Houston SP Andes',
#  412370: 'Mama fleece leggings',
#  412579: 'Walker Knitted Tube',
#  412664: 'Olivier Knitted Scarf',
#  412707: 'Julia',
#  412869: 'Johan Wirstwarmer',
#  412964: 'Emma String (1)',
#  413029: 'Skinny Ankle H.W',
#  413599: 'Bowie Push Mirny',
#  413707: 'Fancy Leggings',
#  413763: 'Handrew Hunterglove',
#  413911: {'BEN basic crewneck SB', 'TP BEN basic crewneck SB'},
#  413965: 'Herman cotton beanie',
#  414066: 'DENNIS onepiece SB',
#  414079: 'Fanny shorts',
#  414102: 'Mikael Glove',
#  414577: 'Manhattan shirt (1)',
#  416089: 'Bracelet Mixalot Pack CO',
#  416157: {'Bruce skinny', 'Bruce skinny 5-pkt'},
#  416175: 'ALGOT 2-p tights',
#  416387: 'Ridley Leather Belt',
#  416511: {'Julia Denim Petite Trs', 'Julia Denim Short TRS'},
#  416905: 'Jaako Knitted Trapper',
#  416911: 'Ludlow Beanie (1)',
#  416961: {'Jade Denim Petite Trs', 'Jade Denim Short TRS'},
#  417088: {'Jacket Trucker', 'Long Trucker Jacket'},
#  417427: {'Classic Vesper watch', 'Cool Vesper watch'},
#  417687: 'Smith Push',
#  417773: 'Star Wool Coat',
#  417855: 'Wyatt Window Buckle Belt',
#  417951: 'Support 20 den 1p tights',
#  418545: 'ALGOT 2-p body',
#  418662: 'Big Nick Beanie',
#  419634: 'Sonja Basic Thin Choker',
#  420049: 'OL TAGE PQ',
#  420264: 'Pack Bowtie Pin Pack',
#  420378: 'Leia lap top case',
#  420387: {'Harrison SP Andes', 'Harrison superpush'},
#  420396: 'Harrison SP Body',
#  420963: 'Kiev pj',
#  421387: 'Isak graphic tee',
#  421941: 'Specter l/s tee',
#  422106: 'Hood W Zip',
#  422393: 'Nina classic flannel PJ',
#  422461: 'Jolly Box Brazilian 3pk',
#  423103: 'Basic jersey cardigan w. frill',
#  423112: 'W Enzo (1)',
#  423539: 'Pack Premium 2-Set',
#  423900: {'Gullan 5-p SG',
#   'Gullan 5-p ankle sock',
#   'Gullan 5-p ankle sock SG'},
#  424022: 'Annabel V neck',
#  424254: 'Chung woven dress',
#  424432: 'Merino 2p socks.',
#  424468: 'Furno Tights',
#  424470: 'Furno Top',
#  424511: 'Swift jumper',
#  425173: 'Eazy Anetti Cap',
#  425217: 'Leila sarong (1)',
#  425218: 'Hudson sarong',
#  425242: 'Vera LL PJ (J)',
#  425526: 'Dawn tee',
#  425529: 'Sleep bag velour',
#  425639: 'Luwin knit jumper',
#  425683: 'ALFONS 2-p cap',
#  425978: 'Cap Ben Baker Boy',
#  426013: {'Vintage Ankle H.W', 'Vintage cropped H.W'},
#  426019: 'Dungaree Alicia',
#  426199: 'Ellen Shortie Daisy Low 3p',
#  426541: {'Morgan Leggings', 'Morgan Price'},
#  426609: 'Fancy correy',
#  426674: 'Noora 5 pack Hipster',
#  427114: {'2P LS GIRLY PJ', '2P LS GIRLY PJ TVP', '2P LS Girly PJ with Frill'},
#  427159: {'Skinny 5pkt Premiumprice 1', 'Skinny 5pkt Trash'},
#  427558: {'Sagat Slim Blz', 'Sagat slim'},
#  427948: 'Winter PJ',
#  428071: 'Ophelia L/S',
#  428291: 'Tigra knitted headband',
#  428454: 'Omega bag',
#  429313: 'Charlotte SP Andes',
#  429314: 'Carla Brazilian Azalea Low',
#  429322: 'Charlotte SP N-Slip Andes',
#  430137: 'Straight H.W Ankle',
#  430157: 'MORRIS onepiece BB',
#  430596: 'Pack Black White',
#  430694: 'Skinny RW shaping',
#  430757: 'Cherry skirt',
#  431034: 'Pixies Leggings',
#  431570: 'Indiana Printed Scarf',
#  432566: {'Net 1p Tights', 'Net Tight'},
#  432984: {'Diamanda', 'Diamanda tights SG'},
#  433252: 'Beatle dress',
#  433275: {'MILLY Onesie pj', 'MILLY onesie', 'MILLY onesie SG'},
#  433414: {'Maria NT 2-pack', 'NT Maria 2-pack'},
#  433444: 'Sara s/s 2-pack',
#  433774: 'Flirty Scarlett earrings',
#  433796: 'FREJA 2-PACK',
#  434080: 'NET 2p socks',
#  434429: 'Mimi superstretch s5',
#  434773: 'ED denim jkt',
#  436083: {'Adhesive Bra', 'Adhesive bra NEW'},
#  436261: 'Control Top 30 den 1p Tights',
#  436570: {'Moscow Cross Bag', 'Moscow cross bag'},
#  436577: 'Shield Terry (1)',
#  436853: {'Diamanda BG', 'Diamanda tights BG'},
#  437129: 'Zoey woven dress',
#  437150: 'Waterfall Winter coat',
#  437582: 'Halloween Skeleton Choker',
#  437668: 'Ethan',
#  437783: 'FOLKE funnelneck hoodie BB',
#  438147: {'Cool Matilda sunglasses', 'Matilda sunglasses'},
#  438333: 'Zoe Sweater',
#  438460: 'Class GP Flion necklace',
#  438499: 'Miracle velvet',
#  438702: 'LENA SNEAKER',
#  438953: 'Seamless biker body BIG FM',
#  439285: {'Stella treggings', 'Stella treggings (1)'},
#  439646: 'June cut padding',
#  439793: 'Jordan',
#  439921: 'Louisa Stay Ups',
#  440144: 'Curtis Tee',
#  440811: 'Lydon Cardigan',
#  441386: {'Jonte Jogger (1)',
#   'Jonte Skinny Jogger 24.99:-',
#   'Jonte Slim Jogger 24.99:-'},
#  441536: 'Vero Tee Embellished',
#  442344: 'Holger Basic Tights (1)',
#  442345: 'Joel basic shorts',
#  442633: 'Tina NT l/s',
#  442786: 'Issa shorts',
#  442915: 'Dina',
#  442957: 'Charlie pull on top',
#  442992: 'Maserati dress',
#  443000: 'Gigi SP Andes',
#  443078: 'CA Berlin',
#  443262: 'Frank Tank',
#  443696: {'BO basic OH BB', 'DENZEL basic OH BB', 'TP BO basic OH BB'},
#  443860: {'Polo S/S Highline', 'Polo S/S Highline TVP', 'S/S Polo Highline'},
#  444325: 'Tiffany dress',
#  444404: 'Elvis Skinny Blz',
#  445358: 'Glans tunic',
#  445400: {'Johan s/l pj BB', 'Johan s/l pj BB (1)'},
#  445419: 'Leon tee',
#  445865: 'Dungaree Dress',
#  445901: 'Halo Half Zip',
#  446147: 'Wallace 2in1 Tee XS-L',
#  446155: 'Lea Shopper',
#  446224: 'Maja Cardigan',
#  446367: 'Kia Wallet',
#  446847: 'Taylor ripped jeans',
#  447201: {'Werter 5-p shaftless SB', 'Werter shaftless SB 5-p'},
#  447264: {'Werter 5-p shaftless BB', 'Werter shaftless BB 5-p'},
#  447596: 'Sindy round s-glass',
#  447664: 'Bea padded bra E&F',
#  447681: 'Trash trucker',
#  447692: 'Petar Sweater (1)',
#  447694: 'Benny Shorts (1)',
#  447795: 'Cloud runner',
#  448262: {'Roll up tee', 'Roll up tee (1)'},
#  448509: {'Perrie Plain Denim TRS', 'Perrie Slim Mom Denim TRS'},
#  448515: {'Kendall Denim TRS', 'Kendall RW Denim TRS', 'Kendall Trash'},
#  448831: 'Tom Solid',
#  449099: {'HAL SHORTS', 'HAL SHORTS.'},
#  449123: 'Correy tee',
#  449175: 'HANA Lace Bikini',
#  449192: 'ROBYN SWIMSUIT',
#  449263: {'Zero Tee', 'Zero Tee (1)'},
#  449555: 'TERMINATOR FANCY TIGHTS',
#  449570: 'CLAY TEE',
#  449648: 'AMY FANCY Swimsuit',
#  449744: 'Karin Medium Support Bra',
#  449897: 'Slim 5pkt',
#  450056: 'SUPREME cropped',
#  450333: 'Hat Flynn Straw',
#  450604: 'Kay Nightshirt (W)',
#  450662: 'Dungaree Shorts',
#  450780: {'Washed Hoodie', 'Washed Hoodie (1)'},
#  450932: 'Canasta joggers',
#  451019: 'PABLO POPOVER SHIRT',
#  451209: 'Flirty Elof studs',
#  451229: 'Skinny 5pkt Malcolm',
#  451243: 'Rufus 5-pkt trousers',
#  451271: 'Oliver chinos',
#  451286: 'Bull blazer',
#  451290: {'Oz SF skinny fit blazer', 'Oz blazer'},
#  451294: 'Rex blazer',
#  451380: 'Bruce denim',
#  451402: 'Bull trousers',
#  451541: '2 PK V-N SS SLIM FIT',
#  451556: 'Binet graphic LS tee',
#  451599: 'Olivier Necktube',
#  451650: 'Beatrice LS body',
#  451704: 'Gary suede micro tote',
#  451720: 'George Beanie',
#  451744: 'Joel straw shopper',
#  451774: 'Big Sarah Cross Bag',
#  452486: 'SABILLA 3 PACK',
#  452511: 'Class Amelie necklace',
#  452516: 'Oz trousers',
#  452616: 'SIVAN 2 PACK',
#  452618: 'Clean Edge 60 den 1p Leggings',
#  452717: 'Corsica',
#  452818: {'5pk basic R socks', '5pk regular', '5pk regular basic'},
#  452851: {'Marie 7-p sock', 'Marie 7-p sock BG', 'Marie 7PACK socks BG'},
#  452898: 'MARION-SHORTS',
#  453016: 'Polly shorts',
#  453026: 'Perfect tee',
#  453028: 'Chiara hood (1)',
#  453065: 'Eivor 7-p shaftless',
#  453134: 'NELLY 2 PACK S/L',
#  453239: {'SLIM FIT: BASIC', 'TVP Slim denim'},
#  453258: 'Chuck Denim jkt (1)',
#  453272: 'SB TRUNKS',
#  453309: 'SB JAKE basic board shorts',
#  453345: 'Ringo hip belt',
#  453358: 'Dalia hip belt',
#  453445: 'BB ASTON',
#  453453: {'BB ASTON PRICEshorts', 'BB ASTON PRICEshorts Curved'},
#  453491: 'Essential: Rex',
#  453585: 'Sassy 3-pack hip belt',
#  453741: 'HILDA PLATFORM',
#  453745: {'ASHTON', 'ASHTON (1)'},
#  453765: 'Capri cardigan',
#  453828: 'BOBBY CUTOUT',
#  453831: 'MAIKEN LACE-UP',
#  453988: 'Eva Tank Top (1)',
#  454008: 'Sheffield woven dress',
#  454128: {'ANTHEA 2-p PJ', 'ANTHEA 2P PJ'},
#  454143: 'Ada woven dress',
#  454196: 'Speedy Tee (1)',
#  454199: 'Jackie coat',
#  454544: {'California Jogger', 'California Jogger (1)'},
#  454602: 'Alfie knit jumper (1)',
#  454804: 'Jogger Wilson 79',
#  455014: {'Marie 7-p SG', 'Marie 7-p ankle sock'},
#  455491: 'Spearmint shorts',
#  455504: 'D-SUIT ESTELLE BASIC',
#  455828: 'Kendall skirt ED',
#  455832: 'Charlotte Soft  Body',
#  455925: 'Yates LS tee',
#  456007: 'Mia playsuit',
#  456011: 'HW shorts',
#  456032: 'Relax Shorts (1)',
#  456163: {'Woody', 'Woody (1)', 'Woody hoodie', 'Woody(1)'},
#  456245: 'Chelsea welldressed waistcoat',
#  456634: 'Jesper tee',
#  456641: 'Clarence Hipster Poppy Mid',
#  456834: 'Emma basic SG',
#  457039: 'Bernie top ED',
#  457059: 'Halie top',
#  457079: 'Rachel dress',
#  457135: 'Moss PU biker',
#  457292: 'Cherry dress',
#  457314: 'Vickan frill dress (1)',
#  457322: 'SB UV Shirt LS',
#  457412: 'Denise shirt',
#  457466: 'Control Top 15 den 1p Tights',
#  457491: 'Derrida Hi-Vis tights',
#  457618: 'Sheffield shirt',
#  457722: {'Axel fancy denim shorts', 'Axel fancy denim shorts (1)'},
#  457755: 'BB UV Raglan',
#  457765: {'Viveka 5-p rib shaftless', 'Viveka 5-p shaftless SG'},
#  457892: 'Fox (1)',
#  458032: 'WILDER',
#  458064: 'Nils running pant',
#  458083: {'BELT BASIC', 'BELT LEATHER', 'LEATHER BELT'},
#  458087: 'Fia longsleeve (1)',
#  458239: {'Tess', 'Tess CN Unique'},
#  458393: {'SERENA 2p tank', 'SERENA 2p tank (1)', 'Serena Tank 2PACK'},
#  458428: {'Cobra Constructed', 'Cobra Constructed (1)'},
#  458543: {'LAZER RAZER push up', 'Lazer Razer Push Up'},
#  458851: 'Poppy cotton shirt',
#  458882: {'Gardenia Shirt', 'Gardenia Shirt (1)'},
#  458924: 'Pablo round neck',
#  458925: 'Javier',
#  459144: 'Vermont fancy',
#  459149: 'Hepburn strap top',
#  459307: 'Hat Filly Straw',
#  459428: 'Jerry Hood',
#  459617: 'Lo Tunic',
#  459756: 'CLEO HIGHLIFT SNEAKER (1)',
#  460302: 'Amiga',
#  460363: 'Sivert sneaker',
#  460891: 'Sabini woven dress',
#  461327: {'Rollerneck Charlie', 'Rollerneck Charlie TVP'},
#  461414: 'OL LINUS PQ loafer',
#  462086: 'Steph SL Set',
#  462128: 'LS PJ',
#  462162: 'Relaxed Skinny 5pkt',
#  462435: {'6P Tanktop Body', '6P Tanktopbody pack', '6PACK Tanktop Body'},
#  463086: 'Eve dress eller annan',
#  463117: 'Rick Suede Cap',
#  463285: 'Kelly',
#  463290: 'Angelica',
#  463536: 'Harry Superpush',
#  463601: 'TUNIS ls 2p (1)',
#  463670: 'Caramella',
#  463970: 'Greta Hipster Ch. (Poppy) L 3p',
#  464277: 'Greta Shortie (Daisy Mid) 3p',
#  464297: 'Greta Thong Mynta Low 3p',
#  464332: 'Zola wide sleeve sweat',
#  464363: 'Camille tee (1)',
#  464454: 'TANJA SKIRT',
#  464541: 'Envy lace',
#  464566: 'Ylva hipster 3pk',
#  464610: 'Bo Reversible',
#  464679: {'HM+ Kim 2p Padded Bra',
#   'HM+ Kim 2p padded',
#   'Kim 2p padded BIG',
#   'Kim 2p padded E&F'},
#  464695: {'ROMY 3-p tanktop', 'ROMY 3PACK tanktop', 'ROMY 3p tanktop'},
#  464848: 'Cindy N-slip (K)',
#  464908: 'Liza Thong Low (Malva) 3pk',
#  464927: 'Ivory Ch. braz. Low Acacia 3pk',
#  465051: 'Sandy off shoulder',
#  465572: 'THEA set',
#  465619: 'RICK l/s henley SB',
#  465655: 'Ginger Thong Maple Low 3p',
#  465816: 'Ring Pack Jose',
#  465862: 'Necklace Donnelly',
#  466006: 'Flirty Bowie Waterbottle',
#  466381: 'Greenville bra (1)',
#  466579: 'Nova Denim 5-pkt',
#  466595: {'Rawley Chinos Slim', 'Rawley chinos'},
#  466599: 'Wave linen',
#  466666: 'Emmy 2-Pack Body',
#  466852: 'Tommy tights',
#  466891: 'City shorts',
#  466917: 'Falkon',
#  466948: {'LOGAN l/s raglan', 'LOGAN l/s raglan SB'},
#  466987: 'Kurt Check',
#  467174: 'MAZER GLAZER top',
#  467191: 'Bobby cotton',
#  467297: 'Ole Cargo',
#  467302: {'Panda dress', 'Panda dress J'},
#  467557: 'Africa velvet skirt',
#  467738: 'Aiden Belt',
#  468013: 'Sherpa cardigan',
#  468255: 'Ariana dress SPEED',
#  468345: 'PETER SLIM FIT POLO',
#  468480: {'Mom Shorts', 'Vintage H.W Shorts'},
#  468591: {'August s/s 2-p snug fit pj', 'August s/s snug fit pj 2-p'},
#  468666: 'SANNA BIKINI BOTTOM',
#  468695: 'Perrie Denim Shorts',
#  468977: 'Selena Shopper',
#  469001: 'Daniel scarf',
#  469021: 'Harry Herringbone',
#  469039: 'Henrik ballerina',
#  469137: 'Juan lace strap top',
#  469271: 'Raven Scarf',
#  469562: {'Skinny denim', 'Skinny denim (1)'},
#  469649: 'Kosmos',
#  469658: 'Spice Girl 3pk hipster',
#  469682: 'Dolores (1)',
#  470111: 'MC Gyda blouse',
#  470167: {'Coski Conscious Scarf', 'Scarf Coski Conscious'},
#  470361: 'Hat Karl Paper Straw',
#  470478: 'MC Hayes trs',
#  470636: 'Ivy jumpsuit W',
#  470766: 'Majken Maxi Dress',
#  470789: {'2p OP Brazilian Low (Acacia)', 'OP Brazilian 2p Low (Acacia)'},
#  470985: 'Vaughan sneaker',
#  471074: '2p OP Shortie Medium (Daisy)',
#  471077: 'Charlotte Suspenderbelt',
#  471456: 'Eclipse blouse',
#  471566: 'OL STAFFAN PQ loafer',
#  471641: 'Li Highwaist brief 2pk',
#  471714: 'Roy Shorts',
#  472064: '6P LS bodypack',
#  472065: 'Novak Ruffle Tank',
#  472243: 'Pollock cap',
#  472320: 'Slash Tee',
#  472341: 'Twist Dress',
#  472447: {'Crawl Printed Tank', 'Crawl Tank'},
#  472755: 'Ben runner gloves',
#  472844: 'Cool Smarty sunglasses',
#  473034: 'ALGOT S/S 2-p body',
#  473497: 'Zoella suede shopper',
#  473507: {'Lindsay shopper', 'Lindsay shopper SPEED'},
#  ...}

# %% [markdown]
# #### Some of the columns have -1 values probably referring to missing data

# %%
print("columns having -1 values: \n")
cols_missing_value=[]
for i in df_articles.columns:
    if (-1 in df_articles[i].value_counts()):
        cols_missing_value.append(i)
print(cols_missing_value)
# Out:
# columns having -1 values:
#
# ['product_type_no', 'graphical_appearance_no', 'colour_group_code', 'perceived_colour_value_id', 'perceived_colour_master_id']

# %% [markdown]
# #### -1 value in all code columns refer to the 'Unknown' category. Therefore keeping -1 values as it is

# %%
product_type[-1]
# Out:
# 'Unknown'

# %%
graphical_appearance[-1]
# Out:
# 'Unknown'

# %%
colour_group[-1]
# Out:
# 'Unknown'

# %%
perceived_colour_value[-1]
# Out:
# 'Unknown'

# %%
perceived_colour_master[-1]
# Out:
# 'Unknown'

# %%
df_cust.to_csv("customers_clean.csv",index=False)
df_articles.to_csv("articles_clean.csv", index=False)

# %% [markdown]
# ## Merging Transaction data with Customer and Articles data to form final dataset

# %%
df_trx.info()

# %%
df_trx.head()

# %%
df=pd.merge(left=df_cust,right=df_trx,on="customer_id",how="left")
df=pd.merge(left=df,right=df_articles,on='article_id',how='left')

# %% [markdown]
# #### Final dataset: df

# %%
df.info()

# %%
df.nunique()

# %%
df.to_csv("hm_data.csv",index=False)
